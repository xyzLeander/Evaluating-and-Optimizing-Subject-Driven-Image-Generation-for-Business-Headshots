# %% [markdown]
# # Set Up

# %% [markdown]
# ## Installs

# %%
pip install numpy accelerate diffusers ftfy bitsandbytes safetensors wandb datasets
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.34.2)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.10/dist-packages (0.30.3)
# Collecting ftfy
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.44.1-py3-none-manylinux_2_24_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (0.4.5)
# Requirement already satisfied: wandb in /usr/local/lib/python3.10/dist-packages (0.18.5)
# Collecting datasets
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.5.0+cu121)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.24.7)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers) (8.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers) (3.16.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from diffusers) (2.32.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers) (10.4.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from ftfy) (0.2.13)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.1.43)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from wandb) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.17.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.10/dist-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (75.1.0)
# Requirement already satisfied: typing-extensions<5,>=4.4 in /usr/local/lib/python3.10/dist-packages (from wandb) (4.12.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.6)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.10)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.17.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (2024.8.30)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers) (3.20.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (3.0.2)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.0 MB/s eta 0:00:00
# Downloading bitsandbytes-0.44.1-py3-none-manylinux_2_24_x86_64.whl (122.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 13.3 MB/s eta 0:00:00
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 26.3 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.2 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 13.6 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.8 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 10.4 MB/s eta 0:00:00
# Installing collected packages: xxhash, ftfy, fsspec, dill, multiprocess, bitsandbytes, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed bitsandbytes-0.44.1 datasets-3.1.0 dill-0.3.8 fsspec-2024.9.0 ftfy-6.3.1 multiprocess-0.70.16 xxhash-3.5.0

# %%
# %pip install -qq git+https://github.com/huggingface/diffusers
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for diffusers (pyproject.toml) ... done

# %%
# !wget -q https://raw.githubusercontent.com/huggingface/diffusers/main/examples/textual_inversion/textual_inversion.py

# %%
# !wget -q https://raw.githubusercontent.com/huggingface/diffusers/main/examples/textual_inversion/textual_inversion_sdxl.py

# %%
# Clone the repo into a temporary directory to gain access to the necessary utils
# !git clone https://github.com/xyzLeander/businessheadshotsthesis.git temp

# Move the contents of the temporary directory to current working directory
# !mv temp/* .

# Remove the temporary directory
# !rm -r temp

# %% [markdown]
# ## Imports

# %%
from diffusers import StableDiffusionPipeline, StableDiffusionXLPipeline, DDIMScheduler, DDPMScheduler, DPMSolverMultistepScheduler
from diffusers.utils import make_image_grid
from string import whitespace
from google.colab import userdata, drive, files
from collections import OrderedDict
from safetensors.torch import load_file
from PIL import Image
from transformers import BlipProcessor, BlipForConditionalGeneration
from datasets import load_dataset

import torch
import os
import shutil
import tensorflow as tf
import datetime
import itertools
import matplotlib.pyplot as plt
import numpy as np
import datasets
import json
import requests
import wandb
import sys
import prep_utils
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]

# %% [markdown]
# ## Environment config

# %%
# !accelerate config default # setup accelerate config
# Out:
# accelerate configuration saved at /root/.cache/huggingface/accelerate/default_config.yaml

# %%
# !wandb login # login weights & biases
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %% [markdown]
# ## Colab Secrets

# %%
os.environ['HF_TOKEN']= userdata.get('Huggingface') # acces huggingface token

# %% [markdown]
# ## Prep

# %%
drive.mount('/content/drive') # access google drive
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Setup Single Training Run

# %%
# key variables
base_dir = '/content/drive/MyDrive/training_images' # path to all training images in google drive
train_directory = '/content/train_images' # path to move the training images to
results_dir = '/content/drive/My Drive/results' # path to result models/embeddings
subfolders = ['textinv', 'dbooth', 'dlora', 'lora'] # subfolders for creating the folder structure

# adjust the parameters below depending on the training process
training_method = 'textinv' # training method: "textinv"
training_model = 'SDXL' # model version: "SDv1.5" or "SDXL"
training_subject = 'leander' # name of subject to train (or directory name referencing the correct subject)

prep_utils.create_folder_structure(results_dir, subfolders) # prepare directory structure in google drive
prep_utils.setup_training_environment(train_directory, results_dir, training_model, training_method, training_subject) # setup for traning
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Root directory already exists: /content/drive/My Drive/results
# Subfolder already exists: /content/drive/My Drive/results/textinv
# Sub-subfolder already exists: /content/drive/My Drive/results/textinv/SDXL
# Sub-subfolder already exists: /content/drive/My Drive/results/textinv/SDv1.5
# Sub-subfolder already exists: /content/drive/My Drive/results/textinv/flux
# Subfolder already exists: /content/drive/My Drive/results/dbooth
# Sub-subfolder already exists: /content/drive/My Drive/results/dbooth/SDXL
# Sub-subfolder already exists: /content/drive/My Drive/results/dbooth/SDv1.5
# Sub-subfolder already exists: /content/drive/My Drive/results/dbooth/flux
# Subfolder already exists: /content/drive/My Drive/results/dlora
# Sub-subfolder already exists: /content/drive/My Drive/results/dlora/SDXL
# Sub-subfolder already exists: /content/drive/My Drive/results/dlora/SDv1.5
# Sub-subfolder already exists: /content/drive/My Drive/results/dlora/flux
# Subfolder already exists: /content/drive/My Drive/results/lora
# Sub-subfolder already exists: /content/drive/My Drive/results/lora/SDXL
# Sub-subfolder already exists: /content/drive/My Drive/results/lora/SDv1.5
# Sub-subfolder already exists: /content/drive/My Drive/results/lora/flux
# Folder structure creation completed!

# %%
images = prep_utils.load_images(base_dir, training_subject) # load subject images from drive
prep_utils.move_images(training_subject, images, train_directory) # move images to environment

# %% [markdown]
# ### Setup Training Loop

# %%
# key variables
base_dir = '/content/drive/MyDrive/training_images' # path to all training images in google drive
train_directory = '/content/train_images' # path to move the training images to
results_dir = '/content/drive/My Drive/results' # path to result models/embeddings
subfolders = ['textinv', 'dbooth', 'dlora', 'lora'] # subfolders for creating the folder structure

subject_list = ['hannah','timh', 'celine', 'marco', 'jannik', 'christoph', 'patrick','timk', 'leander', 'nils'] # list of directory names that reference all subjects

# adjust the parameters below depending on the training process
training_method = 'textinv' # training method: "textinv"
training_model = 'SDXL' # model version: "SDv1.5" or "SDXL"

prep_utils.create_folder_structure(results_dir, subfolders) # prepare directory structure in google drive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Root directory already exists: /content/drive/My Drive/results
# Subfolder already exists: /content/drive/My Drive/results/textinv
# Sub-subfolder already exists: /content/drive/My Drive/results/textinv/SDXL
# Sub-subfolder already exists: /content/drive/My Drive/results/textinv/SDv1.5
# Sub-subfolder already exists: /content/drive/My Drive/results/textinv/flux
# Subfolder already exists: /content/drive/My Drive/results/dbooth
# Sub-subfolder already exists: /content/drive/My Drive/results/dbooth/SDXL
# Sub-subfolder already exists: /content/drive/My Drive/results/dbooth/SDv1.5
# Sub-subfolder already exists: /content/drive/My Drive/results/dbooth/flux
# Subfolder already exists: /content/drive/My Drive/results/dlora
# Sub-subfolder already exists: /content/drive/My Drive/results/dlora/SDXL
# Sub-subfolder already exists: /content/drive/My Drive/results/dlora/SDv1.5
# Sub-subfolder already exists: /content/drive/My Drive/results/dlora/flux
# Subfolder already exists: /content/drive/My Drive/results/lora
# Sub-subfolder already exists: /content/drive/My Drive/results/lora/SDXL
# Sub-subfolder already exists: /content/drive/My Drive/results/lora/SDv1.5
# Sub-subfolder already exists: /content/drive/My Drive/results/lora/flux
# Folder structure creation completed!

# %% [markdown]
# # Trainings

# %% [markdown]
# ## Training textual inversion embed (SD 1.5)

# %%
# check environment variables before running training
# !echo $TRAIN_DIR
# !echo $OUTPUT_DIR
# !echo $MODEL_NAME
# !echo $VALID_PROMPT
# !echo $RESOLUTION
# !echo $PLACEHOLDER_TOKEN
# !echo $INITIALIZER_TOKEN
# Out:
# /content/train_images
# /content/drive/My Drive/results/textinv/SDXL/leander
# stabilityai/stable-diffusion-xl-base-1.0
# business headshot of a <sks> man
# 1024
# <sks>
# man

# %%
# Check if the MODEL_NAME is set correctly
if os.environ.get('MODEL_NAME') == 'benjamin-paine/stable-diffusion-v1-5':
    # Define the parameters for the training script
    train_params = {
        "pretrained_model_name_or_path": os.environ.get('MODEL_NAME'),
        "train_data_dir": os.environ.get('TRAIN_DIR'),
        "learnable_property": "object",
        "placeholder_token": os.environ.get('PLACEHOLDER_TOKEN'),
        "initializer_token": os.environ.get('INITIALIZER_TOKEN'),
        "resolution": os.environ.get('RESOLUTION'),
        "train_batch_size": 4,
        "num_vectors": 8,
        "gradient_accumulation_steps": 1,
        "max_train_steps": 2000,
        "learning_rate": 1e-04,
        # "scale_lr": True,
        "lr_scheduler": "constant",
        "lr_warmup_steps": 0,
        "validation_prompt": os.environ.get('VALID_PROMPT'),
        "validation_steps":100,
        "output_dir": os.environ.get('OUTPUT_DIR'),
        "mixed_precision": "fp16",
        "checkpointing_steps": 100,
        "report_to": "wandb",
        "seed": 42,
    }

    # Save the parameters to a text file
    params_file = os.path.join(os.environ.get('OUTPUT_DIR'), "training_params.txt")
    with open(params_file, "w") as f:
        for key, value in train_params.items():
            f.write(f"{key}: {value}\n")

    # Construct the command to run the training script
    # !accelerate launch textual_inversion.py \
        --pretrained_model_name_or_path="{train_params['pretrained_model_name_or_path']}"  \
        --output_dir="{train_params['output_dir']}" \
        --train_data_dir="{train_params['train_data_dir']}" \
        --resolution={train_params['resolution']} \
        --learnable_property="{train_params['learnable_property']}" \
        --initializer_token="{train_params['initializer_token']}" \
        --placeholder_token="{train_params['placeholder_token']}" \
        --train_batch_size="{train_params['train_batch_size']}" \
        --gradient_accumulation_steps={train_params['gradient_accumulation_steps']} \
        --num_vectors={train_params['num_vectors']} \
        --resume_from_checkpoint="latest" \
        --max_train_steps={train_params['max_train_steps']} \
        --checkpointing_steps={train_params['checkpointing_steps']} \
        --mixed_precision="{train_params['mixed_precision']}" \
        --learning_rate={train_params['learning_rate']} --lr_scheduler="{train_params['lr_scheduler']}" --lr_warmup_steps={train_params['lr_warmup_steps']} \
        --validation_steps={train_params['validation_steps']} --validation_prompt="{train_params['validation_prompt']}" --report_to="{train_params['report_to']}" \
        --seed={train_params['seed']}
else:
    print("Cannot run training script. Environment variable MODEL_NAME is not set correctly. Set MODEL_NAME correctly or use appropriate training script.")
# Out:
# Cannot run training script. Environment variable MODEL_NAME is not set correctly. Set MODEL_NAME correctly or use appropriate training script.

# %% [markdown]
# ## Training Loop (SD 1.5)

# %%
for subject in subject_list:
  prep_utils.empty_directory(train_directory) # empties train_directory to prepare for training of the next subject

  training_subject = subject

  prep_utils.setup_training_environment(train_directory, results_dir, training_model, training_method, training_subject)
  images = prep_utils.load_images(base_dir, training_subject)
  prep_utils.move_images(training_subject, images, train_directory)

  # Check if the MODEL_NAME is set correctly
  if os.environ.get('MODEL_NAME') == 'benjamin-paine/stable-diffusion-v1-5':
      # Define the parameters for the training script
      train_params = {
          "pretrained_model_name_or_path": os.environ.get('MODEL_NAME'),
          "train_data_dir": os.environ.get('TRAIN_DIR'),
          "learnable_property": "object",
          "placeholder_token": os.environ.get('PLACEHOLDER_TOKEN'),
          "initializer_token": os.environ.get('INITIALIZER_TOKEN'),
          "resolution": os.environ.get('RESOLUTION'),
          "train_batch_size": 4,
          "num_vectors": 8,
          "gradient_accumulation_steps": 1,
          "max_train_steps": 2000,
          "learning_rate": 1e-04,
          # "scale_lr": True,
          "lr_scheduler": "constant",
          "lr_warmup_steps": 0,
          "validation_prompt": os.environ.get('VALID_PROMPT'),
          "validation_steps":100,
          "output_dir": os.environ.get('OUTPUT_DIR'),
          "mixed_precision": "fp16",
          "checkpointing_steps": 100,
          "report_to": "wandb",
          "seed": 42,
      }

      # Save the parameters to a text file
      params_file = os.path.join(os.environ.get('OUTPUT_DIR'), "training_params.txt")
      with open(params_file, "w") as f:
          for key, value in train_params.items():
              f.write(f"{key}: {value}\n")

      # Construct the command to run the training script
      # !accelerate launch textual_inversion.py \
          --pretrained_model_name_or_path="{train_params['pretrained_model_name_or_path']}"  \
          --output_dir="{train_params['output_dir']}" \
          --train_data_dir="{train_params['train_data_dir']}" \
          --resolution={train_params['resolution']} \
          --learnable_property="{train_params['learnable_property']}" \
          --initializer_token="{train_params['initializer_token']}" \
          --placeholder_token="{train_params['placeholder_token']}" \
          --train_batch_size="{train_params['train_batch_size']}" \
          --gradient_accumulation_steps={train_params['gradient_accumulation_steps']} \
          --num_vectors={train_params['num_vectors']} \
          --resume_from_checkpoint="latest" \
          --max_train_steps={train_params['max_train_steps']} \
          --checkpointing_steps={train_params['checkpointing_steps']} \
          --mixed_precision="{train_params['mixed_precision']}" \
          --learning_rate={train_params['learning_rate']} --lr_scheduler="{train_params['lr_scheduler']}" --lr_warmup_steps={train_params['lr_warmup_steps']} \
          --validation_steps={train_params['validation_steps']} --validation_prompt="{train_params['validation_prompt']}" --report_to="{train_params['report_to']}" \
          --seed={train_params['seed']}
  else:
      print("Cannot run training script. Environment variable MODEL_NAME is not set correctly. Set MODEL_NAME correctly or use appropriate training script.")

  prep_utils.empty_directory(train_directory) # empties train_directory to prepare for training of the next subject
# Out:
# Directory does not exist: /content/train_images
# Saved /content/train_images/timk_1.jpg
# Saved /content/train_images/timk_2.jpg
# Saved /content/train_images/timk_3.jpg
# Saved /content/train_images/timk_4.jpg
# Saved /content/train_images/timk_5.jpg
# Saved /content/train_images/timk_6.jpg
# Saved /content/train_images/timk_7.jpg
# Saved /content/train_images/timk_8.jpg
# Saved /content/train_images/timk_9.jpg
# Saved /content/train_images/timk_10.jpg
# 2024-11-06 11:01:47.545880: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-06 11:01:47.567149: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-06 11:01:47.573493: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-06 11:01:48.764787: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:494: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(**kwargs)
# 11/06/2024 11:01:50 - INFO - __main__ - Distributed environment: NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: fp16
#
# tokenizer/tokenizer_config.json: 100% 806/806 [00:00<00:00, 5.85MB/s]
# tokenizer/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 4.34MB/s]
# tokenizer/merges.txt: 100% 525k/525k [00:00<00:00, 2.27MB/s]
# tokenizer/special_tokens_map.json: 100% 472/472 [00:00<00:00, 3.65MB/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# scheduler/scheduler_config.json: 100% 308/308 [00:00<00:00, 2.34MB/s]
# {'timestep_spacing', 'rescale_betas_zero_snr', 'thresholding', 'dynamic_thresholding_ratio', 'clip_sample_range', 'variance_type', 'sample_max_value', 'prediction_type'} was not found in config. Values will be initialized to default values.
# text_encoder/config.json: 100% 617/617 [00:00<00:00, 4.22MB/s]
# model.safetensors: 100% 492M/492M [00:12<00:00, 39.1MB/s]
# vae/config.json: 100% 547/547 [00:00<00:00, 3.84MB/s]
# diffusion_pytorch_model.safetensors: 100% 335M/335M [00:07<00:00, 42.1MB/s]
# {'latents_mean', 'use_post_quant_conv', 'mid_block_add_attention', 'force_upcast', 'scaling_factor', 'use_quant_conv', 'shift_factor', 'latents_std'} was not found in config. Values will be initialized to default values.
# unet/config.json: 100% 743/743 [00:00<00:00, 5.63MB/s]
# diffusion_pytorch_model.safetensors: 100% 3.44G/3.44G [01:23<00:00, 41.4MB/s]
# {'mid_block_only_cross_attention', 'class_embeddings_concat', 'addition_embed_type', 'num_class_embeds', 'time_embedding_dim', 'addition_embed_type_num_heads', 'use_linear_projection', 'time_cond_proj_dim', 'resnet_skip_time_act', 'conv_out_kernel', 'num_attention_heads', 'time_embedding_act_fn', 'time_embedding_type', 'addition_time_embed_dim', 'conv_in_kernel', 'reverse_transformer_layers_per_block', 'mid_block_type', 'class_embed_type', 'attention_type', 'cross_attention_norm', 'only_cross_attention', 'dropout', 'resnet_time_scale_shift', 'projection_class_embeddings_input_dim', 'encoder_hid_dim_type', 'resnet_out_scale_factor', 'transformer_layers_per_block', 'dual_cross_attention', 'upcast_attention', 'encoder_hid_dim', 'timestep_post_act'} was not found in config. Values will be initialized to default values.
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: lnikolei (lnikolei-university-of-cologne). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.5
# wandb: Run data is saved locally in /content/wandb/run-20241106_110347-528hpc1g
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run morning-leaf-89
# wandb: ⭐️ View project at https://wandb.ai/lnikolei-university-of-cologne/textual_inversion
# wandb: 🚀 View run at https://wandb.ai/lnikolei-university-of-cologne/textual_inversion/runs/528hpc1g
# 11/06/2024 11:03:48 - INFO - __main__ - ***** Running training *****
# 11/06/2024 11:03:48 - INFO - __main__ -   Num examples = 1000
# 11/06/2024 11:03:48 - INFO - __main__ -   Num Epochs = 8
# 11/06/2024 11:03:48 - INFO - __main__ -   Instantaneous batch size per device = 4
# 11/06/2024 11:03:48 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 4
# 11/06/2024 11:03:48 - INFO - __main__ -   Gradient Accumulation steps = 1
# 11/06/2024 11:03:48 - INFO - __main__ -   Total optimization steps = 2000
# Resuming from checkpoint checkpoint-300
# 11/06/2024 11:03:48 - INFO - accelerate.accelerator - Loading states from /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-300
# 11/06/2024 11:04:04 - INFO - accelerate.checkpointing - All model weights loaded successfully
# /usr/local/lib/python3.10/dist-packages/accelerate/checkpointing.py:228: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   optimizer_state = torch.load(input_optimizer_file, map_location=map_location)
# 11/06/2024 11:04:07 - INFO - accelerate.checkpointing - All optimizer states loaded successfully
# /usr/local/lib/python3.10/dist-packages/accelerate/checkpointing.py:236: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   scheduler.load_state_dict(torch.load(input_scheduler_file))
# 11/06/2024 11:04:08 - INFO - accelerate.checkpointing - All scheduler states loaded successfully
# 11/06/2024 11:04:08 - INFO - accelerate.checkpointing - All dataloader sampler states loaded successfully
# /usr/local/lib/python3.10/dist-packages/accelerate/checkpointing.py:260: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   scaler.load_state_dict(torch.load(input_scaler_file))
# 11/06/2024 11:04:09 - INFO - accelerate.checkpointing - GradScaler state loaded successfully
# /usr/local/lib/python3.10/dist-packages/accelerate/checkpointing.py:265: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   states = torch.load(input_dir.joinpath(f"{RNG_STATE_NAME}_{process_index}.pkl"))
# 11/06/2024 11:04:09 - INFO - accelerate.checkpointing - All random states loaded successfully
# 11/06/2024 11:04:09 - INFO - accelerate.accelerator - Loading in 0 custom states
# Steps:  15% 300/2000 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:825: UserWarning: cuDNN SDPA backward got grad_output.strides() != output.strides(), attempting to materialize a grad_output with matching strides... (Triggered internally at ../aten/src/ATen/native/cudnn/MHA.cpp:674.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Steps:  20% 400/2000 [01:42<24:20,  1.10it/s, loss=0.0488, lr=0.0001]11/06/2024 11:05:52 - INFO - accelerate.accelerator - Saving current state to /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-400
# 11/06/2024 11:05:53 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-400/model.safetensors
# 11/06/2024 11:05:54 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-400/optimizer.bin
# 11/06/2024 11:05:54 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-400/scheduler.bin
# 11/06/2024 11:05:54 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-400/sampler.bin
# 11/06/2024 11:05:54 - INFO - accelerate.checkpointing - Gradient scaler state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-400/scaler.pt
# 11/06/2024 11:05:56 - INFO - accelerate.checkpointing - Random states saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-400/random_states_0.pkl
# 11/06/2024 11:05:56 - INFO - __main__ - Saved state to /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-400
# 11/06/2024 11:05:56 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
#
# model_index.json: 100% 543/543 [00:00<00:00, 2.24MB/s]
#
# Fetching 3 files:   0% 0/3 [00:00<?, ?it/s]
#
# (…)ature_extractor/preprocessor_config.json: 100% 342/342 [00:00<00:00, 1.04MB/s]
#
# Fetching 3 files: 100% 3/3 [00:00<00:00,  5.69it/s]
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/6 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# Loaded feature_extractor as CLIPFeatureExtractor from `feature_extractor` subfolder of benjamin-paine/stable-diffusion-v1-5.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of benjamin-paine/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 6/6 [00:00<00:00, 648.10it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# {'final_sigmas_type', 'use_beta_sigmas', 'solver_type', 'use_karras_sigmas', 'use_exponential_sigmas', 'timestep_spacing', 'lower_order_final', 'thresholding', 'lambda_min_clipped', 'dynamic_thresholding_ratio', 'rescale_betas_zero_snr', 'solver_order', 'variance_type', 'sample_max_value', 'prediction_type', 'euler_at_final', 'algorithm_type', 'use_lu_lambdas'} was not found in config. Values will be initialized to default values.
# Steps:  25% 500/2000 [03:32<21:44,  1.15it/s, loss=0.0628, lr=0.0001]11/06/2024 11:07:42 - INFO - __main__ - Saving embeddings
# 11/06/2024 11:07:42 - INFO - accelerate.accelerator - Saving current state to /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-500
# 11/06/2024 11:07:43 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-500/model.safetensors
# 11/06/2024 11:07:44 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-500/optimizer.bin
# 11/06/2024 11:07:44 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-500/scheduler.bin
# 11/06/2024 11:07:44 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-500/sampler.bin
# 11/06/2024 11:07:44 - INFO - accelerate.checkpointing - Gradient scaler state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-500/scaler.pt
# 11/06/2024 11:07:44 - INFO - accelerate.checkpointing - Random states saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-500/random_states_0.pkl
# 11/06/2024 11:07:44 - INFO - __main__ - Saved state to /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-500
# 11/06/2024 11:07:44 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/6 [00:00<?, ?it/s]Loaded feature_extractor as CLIPFeatureExtractor from `feature_extractor` subfolder of benjamin-paine/stable-diffusion-v1-5.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of benjamin-paine/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 6/6 [00:00<00:00, 1773.12it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# {'final_sigmas_type', 'use_beta_sigmas', 'solver_type', 'use_karras_sigmas', 'use_exponential_sigmas', 'timestep_spacing', 'lower_order_final', 'thresholding', 'lambda_min_clipped', 'dynamic_thresholding_ratio', 'rescale_betas_zero_snr', 'solver_order', 'variance_type', 'sample_max_value', 'prediction_type', 'euler_at_final', 'algorithm_type', 'use_lu_lambdas'} was not found in config. Values will be initialized to default values.
# Steps:  30% 600/2000 [05:18<26:17,  1.13s/it, loss=0.0351, lr=0.0001]11/06/2024 11:09:28 - INFO - accelerate.accelerator - Saving current state to /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-600
# 11/06/2024 11:09:29 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-600/model.safetensors
# 11/06/2024 11:09:30 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-600/optimizer.bin
# 11/06/2024 11:09:32 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-600/scheduler.bin
# 11/06/2024 11:09:32 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-600/sampler.bin
# 11/06/2024 11:09:32 - INFO - accelerate.checkpointing - Gradient scaler state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-600/scaler.pt
# 11/06/2024 11:09:32 - INFO - accelerate.checkpointing - Random states saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-600/random_states_0.pkl
# 11/06/2024 11:09:32 - INFO - __main__ - Saved state to /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-600
# 11/06/2024 11:09:32 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/6 [00:00<?, ?it/s]Loaded feature_extractor as CLIPFeatureExtractor from `feature_extractor` subfolder of benjamin-paine/stable-diffusion-v1-5.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of benjamin-paine/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 6/6 [00:00<00:00, 1836.92it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# {'final_sigmas_type', 'use_beta_sigmas', 'solver_type', 'use_karras_sigmas', 'use_exponential_sigmas', 'timestep_spacing', 'lower_order_final', 'thresholding', 'lambda_min_clipped', 'dynamic_thresholding_ratio', 'rescale_betas_zero_snr', 'solver_order', 'variance_type', 'sample_max_value', 'prediction_type', 'euler_at_final', 'algorithm_type', 'use_lu_lambdas'} was not found in config. Values will be initialized to default values.
# Steps:  35% 700/2000 [07:06<21:31,  1.01it/s, loss=0.0656, lr=0.0001]11/06/2024 11:11:16 - INFO - accelerate.accelerator - Saving current state to /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-700
# 11/06/2024 11:11:17 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-700/model.safetensors
# 11/06/2024 11:11:18 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-700/optimizer.bin
# 11/06/2024 11:11:18 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-700/scheduler.bin
# 11/06/2024 11:11:18 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-700/sampler.bin
# 11/06/2024 11:11:18 - INFO - accelerate.checkpointing - Gradient scaler state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-700/scaler.pt
# 11/06/2024 11:11:18 - INFO - accelerate.checkpointing - Random states saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-700/random_states_0.pkl
# 11/06/2024 11:11:18 - INFO - __main__ - Saved state to /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-700
# 11/06/2024 11:11:18 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/6 [00:00<?, ?it/s]Loaded feature_extractor as CLIPFeatureExtractor from `feature_extractor` subfolder of benjamin-paine/stable-diffusion-v1-5.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of benjamin-paine/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 6/6 [00:00<00:00, 1809.06it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# {'final_sigmas_type', 'use_beta_sigmas', 'solver_type', 'use_karras_sigmas', 'use_exponential_sigmas', 'timestep_spacing', 'lower_order_final', 'thresholding', 'lambda_min_clipped', 'dynamic_thresholding_ratio', 'rescale_betas_zero_snr', 'solver_order', 'variance_type', 'sample_max_value', 'prediction_type', 'euler_at_final', 'algorithm_type', 'use_lu_lambdas'} was not found in config. Values will be initialized to default values.
# Steps:  40% 800/2000 [08:52<15:53,  1.26it/s, loss=0.159, lr=0.0001]11/06/2024 11:13:02 - INFO - accelerate.accelerator - Saving current state to /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-800
# 11/06/2024 11:13:03 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-800/model.safetensors
# 11/06/2024 11:13:04 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-800/optimizer.bin
# 11/06/2024 11:13:06 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-800/scheduler.bin
# 11/06/2024 11:13:06 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-800/sampler.bin
# 11/06/2024 11:13:06 - INFO - accelerate.checkpointing - Gradient scaler state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-800/scaler.pt
# 11/06/2024 11:13:06 - INFO - accelerate.checkpointing - Random states saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-800/random_states_0.pkl
# 11/06/2024 11:13:06 - INFO - __main__ - Saved state to /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-800
# 11/06/2024 11:13:06 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/6 [00:00<?, ?it/s]Loaded feature_extractor as CLIPFeatureExtractor from `feature_extractor` subfolder of benjamin-paine/stable-diffusion-v1-5.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of benjamin-paine/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 6/6 [00:00<00:00, 1831.31it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# {'final_sigmas_type', 'use_beta_sigmas', 'solver_type', 'use_karras_sigmas', 'use_exponential_sigmas', 'timestep_spacing', 'lower_order_final', 'thresholding', 'lambda_min_clipped', 'dynamic_thresholding_ratio', 'rescale_betas_zero_snr', 'solver_order', 'variance_type', 'sample_max_value', 'prediction_type', 'euler_at_final', 'algorithm_type', 'use_lu_lambdas'} was not found in config. Values will be initialized to default values.
# Steps:  45% 900/2000 [10:38<16:32,  1.11it/s, loss=0.258, lr=0.0001]11/06/2024 11:14:48 - INFO - accelerate.accelerator - Saving current state to /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-900
# 11/06/2024 11:14:50 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-900/model.safetensors
# 11/06/2024 11:14:51 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-900/optimizer.bin
# 11/06/2024 11:14:51 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-900/scheduler.bin
# 11/06/2024 11:14:51 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-900/sampler.bin
# 11/06/2024 11:14:51 - INFO - accelerate.checkpointing - Gradient scaler state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-900/scaler.pt
# 11/06/2024 11:14:51 - INFO - accelerate.checkpointing - Random states saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-900/random_states_0.pkl
# 11/06/2024 11:14:51 - INFO - __main__ - Saved state to /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-900
# 11/06/2024 11:14:51 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/6 [00:00<?, ?it/s]Loaded feature_extractor as CLIPFeatureExtractor from `feature_extractor` subfolder of benjamin-paine/stable-diffusion-v1-5.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of benjamin-paine/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 6/6 [00:00<00:00, 1784.43it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# {'final_sigmas_type', 'use_beta_sigmas', 'solver_type', 'use_karras_sigmas', 'use_exponential_sigmas', 'timestep_spacing', 'lower_order_final', 'thresholding', 'lambda_min_clipped', 'dynamic_thresholding_ratio', 'rescale_betas_zero_snr', 'solver_order', 'variance_type', 'sample_max_value', 'prediction_type', 'euler_at_final', 'algorithm_type', 'use_lu_lambdas'} was not found in config. Values will be initialized to default values.
# Steps:  50% 1000/2000 [12:27<14:47,  1.13it/s, loss=0.0973, lr=0.0001]11/06/2024 11:16:37 - INFO - __main__ - Saving embeddings
# 11/06/2024 11:16:37 - INFO - accelerate.accelerator - Saving current state to /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1000
# 11/06/2024 11:16:39 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1000/model.safetensors
# 11/06/2024 11:16:40 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1000/optimizer.bin
# 11/06/2024 11:16:40 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1000/scheduler.bin
# 11/06/2024 11:16:40 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1000/sampler.bin
# 11/06/2024 11:16:40 - INFO - accelerate.checkpointing - Gradient scaler state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1000/scaler.pt
# 11/06/2024 11:16:40 - INFO - accelerate.checkpointing - Random states saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1000/random_states_0.pkl
# 11/06/2024 11:16:40 - INFO - __main__ - Saved state to /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1000
# 11/06/2024 11:16:40 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/6 [00:00<?, ?it/s]Loaded feature_extractor as CLIPFeatureExtractor from `feature_extractor` subfolder of benjamin-paine/stable-diffusion-v1-5.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of benjamin-paine/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 6/6 [00:00<00:00, 1862.34it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# {'final_sigmas_type', 'use_beta_sigmas', 'solver_type', 'use_karras_sigmas', 'use_exponential_sigmas', 'timestep_spacing', 'lower_order_final', 'thresholding', 'lambda_min_clipped', 'dynamic_thresholding_ratio', 'rescale_betas_zero_snr', 'solver_order', 'variance_type', 'sample_max_value', 'prediction_type', 'euler_at_final', 'algorithm_type', 'use_lu_lambdas'} was not found in config. Values will be initialized to default values.
# Steps:  55% 1100/2000 [14:13<12:44,  1.18it/s, loss=0.0631, lr=0.0001]11/06/2024 11:18:23 - INFO - accelerate.accelerator - Saving current state to /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1100
# 11/06/2024 11:18:24 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1100/model.safetensors
# 11/06/2024 11:18:25 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1100/optimizer.bin
# 11/06/2024 11:18:25 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1100/scheduler.bin
# 11/06/2024 11:18:25 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1100/sampler.bin
# 11/06/2024 11:18:25 - INFO - accelerate.checkpointing - Gradient scaler state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1100/scaler.pt
# 11/06/2024 11:18:25 - INFO - accelerate.checkpointing - Random states saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1100/random_states_0.pkl
# 11/06/2024 11:18:25 - INFO - __main__ - Saved state to /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1100
# 11/06/2024 11:18:25 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/6 [00:00<?, ?it/s]Loaded feature_extractor as CLIPFeatureExtractor from `feature_extractor` subfolder of benjamin-paine/stable-diffusion-v1-5.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of benjamin-paine/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 6/6 [00:00<00:00, 1841.76it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# {'final_sigmas_type', 'use_beta_sigmas', 'solver_type', 'use_karras_sigmas', 'use_exponential_sigmas', 'timestep_spacing', 'lower_order_final', 'thresholding', 'lambda_min_clipped', 'dynamic_thresholding_ratio', 'rescale_betas_zero_snr', 'solver_order', 'variance_type', 'sample_max_value', 'prediction_type', 'euler_at_final', 'algorithm_type', 'use_lu_lambdas'} was not found in config. Values will be initialized to default values.
# Steps:  60% 1200/2000 [16:02<12:52,  1.03it/s, loss=0.185, lr=0.0001]11/06/2024 11:20:12 - INFO - accelerate.accelerator - Saving current state to /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1200
# 11/06/2024 11:20:14 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1200/model.safetensors
# 11/06/2024 11:20:14 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1200/optimizer.bin
# 11/06/2024 11:20:14 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1200/scheduler.bin
# 11/06/2024 11:20:14 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1200/sampler.bin
# 11/06/2024 11:20:14 - INFO - accelerate.checkpointing - Gradient scaler state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1200/scaler.pt
# 11/06/2024 11:20:14 - INFO - accelerate.checkpointing - Random states saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1200/random_states_0.pkl
# 11/06/2024 11:20:14 - INFO - __main__ - Saved state to /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1200
# 11/06/2024 11:20:14 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/6 [00:00<?, ?it/s]Loaded feature_extractor as CLIPFeatureExtractor from `feature_extractor` subfolder of benjamin-paine/stable-diffusion-v1-5.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of benjamin-paine/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 6/6 [00:00<00:00, 1733.90it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# {'final_sigmas_type', 'use_beta_sigmas', 'solver_type', 'use_karras_sigmas', 'use_exponential_sigmas', 'timestep_spacing', 'lower_order_final', 'thresholding', 'lambda_min_clipped', 'dynamic_thresholding_ratio', 'rescale_betas_zero_snr', 'solver_order', 'variance_type', 'sample_max_value', 'prediction_type', 'euler_at_final', 'algorithm_type', 'use_lu_lambdas'} was not found in config. Values will be initialized to default values.
# Steps:  65% 1300/2000 [17:48<09:17,  1.26it/s, loss=0.206, lr=0.0001]11/06/2024 11:21:58 - INFO - accelerate.accelerator - Saving current state to /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1300
# 11/06/2024 11:21:59 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1300/model.safetensors
# 11/06/2024 11:22:00 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1300/optimizer.bin
# 11/06/2024 11:22:00 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1300/scheduler.bin
# 11/06/2024 11:22:00 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1300/sampler.bin
# 11/06/2024 11:22:00 - INFO - accelerate.checkpointing - Gradient scaler state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1300/scaler.pt
# 11/06/2024 11:22:00 - INFO - accelerate.checkpointing - Random states saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1300/random_states_0.pkl
# 11/06/2024 11:22:00 - INFO - __main__ - Saved state to /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1300
# 11/06/2024 11:22:00 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/6 [00:00<?, ?it/s]Loaded feature_extractor as CLIPFeatureExtractor from `feature_extractor` subfolder of benjamin-paine/stable-diffusion-v1-5.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of benjamin-paine/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 6/6 [00:00<00:00, 1800.26it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# {'final_sigmas_type', 'use_beta_sigmas', 'solver_type', 'use_karras_sigmas', 'use_exponential_sigmas', 'timestep_spacing', 'lower_order_final', 'thresholding', 'lambda_min_clipped', 'dynamic_thresholding_ratio', 'rescale_betas_zero_snr', 'solver_order', 'variance_type', 'sample_max_value', 'prediction_type', 'euler_at_final', 'algorithm_type', 'use_lu_lambdas'} was not found in config. Values will be initialized to default values.
# Steps:  70% 1400/2000 [19:33<10:15,  1.03s/it, loss=0.0926, lr=0.0001]11/06/2024 11:23:43 - INFO - accelerate.accelerator - Saving current state to /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1400
# 11/06/2024 11:23:44 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1400/model.safetensors
# 11/06/2024 11:23:45 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1400/optimizer.bin
# 11/06/2024 11:23:45 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1400/scheduler.bin
# 11/06/2024 11:23:45 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1400/sampler.bin
# 11/06/2024 11:23:45 - INFO - accelerate.checkpointing - Gradient scaler state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1400/scaler.pt
# 11/06/2024 11:23:45 - INFO - accelerate.checkpointing - Random states saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1400/random_states_0.pkl
# 11/06/2024 11:23:45 - INFO - __main__ - Saved state to /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1400
# 11/06/2024 11:23:45 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/6 [00:00<?, ?it/s]Loaded feature_extractor as CLIPFeatureExtractor from `feature_extractor` subfolder of benjamin-paine/stable-diffusion-v1-5.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of benjamin-paine/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 6/6 [00:00<00:00, 1831.71it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# {'final_sigmas_type', 'use_beta_sigmas', 'solver_type', 'use_karras_sigmas', 'use_exponential_sigmas', 'timestep_spacing', 'lower_order_final', 'thresholding', 'lambda_min_clipped', 'dynamic_thresholding_ratio', 'rescale_betas_zero_snr', 'solver_order', 'variance_type', 'sample_max_value', 'prediction_type', 'euler_at_final', 'algorithm_type', 'use_lu_lambdas'} was not found in config. Values will be initialized to default values.
# Steps:  75% 1500/2000 [21:19<07:51,  1.06it/s, loss=0.225, lr=0.0001]11/06/2024 11:25:29 - INFO - __main__ - Saving embeddings
# 11/06/2024 11:25:29 - INFO - accelerate.accelerator - Saving current state to /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1500
# 11/06/2024 11:25:31 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1500/model.safetensors
# 11/06/2024 11:25:32 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1500/optimizer.bin
# 11/06/2024 11:25:32 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1500/scheduler.bin
# 11/06/2024 11:25:32 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1500/sampler.bin
# 11/06/2024 11:25:32 - INFO - accelerate.checkpointing - Gradient scaler state saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1500/scaler.pt
# 11/06/2024 11:25:32 - INFO - accelerate.checkpointing - Random states saved in /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1500/random_states_0.pkl
# 11/06/2024 11:25:32 - INFO - __main__ - Saved state to /content/drive/My Drive/results/textinv/SDv1.5/timk/checkpoint-1500
# 11/06/2024 11:25:32 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/6 [00:00<?, ?it/s]Loaded feature_extractor as CLIPFeatureExtractor from `feature_extractor` subfolder of benjamin-paine/stable-diffusion-v1-5.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of benjamin-paine/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 6/6 [00:00<00:00, 1586.35it/s]
# ...
# {'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/6 [00:00<?, ?it/s]Loaded feature_extractor as CLIPFeatureExtractor from `feature_extractor` subfolder of benjamin-paine/stable-diffusion-v1-5.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of benjamin-paine/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 6/6 [00:00<00:00, 1716.98it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# {'variance_type', 'algorithm_type', 'use_beta_sigmas', 'use_exponential_sigmas', 'solver_type', 'final_sigmas_type', 'use_lu_lambdas', 'dynamic_thresholding_ratio', 'timestep_spacing', 'prediction_type', 'lower_order_final', 'sample_max_value', 'rescale_betas_zero_snr', 'lambda_min_clipped', 'thresholding', 'euler_at_final', 'use_karras_sigmas', 'solver_order'} was not found in config. Values will be initialized to default values.
# Steps:  85% 1700/2000 [33:31<05:09,  1.03s/it, loss=0.109, lr=0.0001]11/06/2024 12:35:22 - INFO - accelerate.accelerator - Saving current state to /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-1700
# 11/06/2024 12:35:23 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-1700/model.safetensors
# 11/06/2024 12:35:24 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-1700/optimizer.bin
# 11/06/2024 12:35:24 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-1700/scheduler.bin
# 11/06/2024 12:35:24 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-1700/sampler.bin
# 11/06/2024 12:35:24 - INFO - accelerate.checkpointing - Gradient scaler state saved in /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-1700/scaler.pt
# 11/06/2024 12:35:24 - INFO - accelerate.checkpointing - Random states saved in /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-1700/random_states_0.pkl
# 11/06/2024 12:35:24 - INFO - __main__ - Saved state to /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-1700
# 11/06/2024 12:35:24 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/6 [00:00<?, ?it/s]Loaded feature_extractor as CLIPFeatureExtractor from `feature_extractor` subfolder of benjamin-paine/stable-diffusion-v1-5.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of benjamin-paine/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 6/6 [00:00<00:00, 1778.13it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# {'variance_type', 'algorithm_type', 'use_beta_sigmas', 'use_exponential_sigmas', 'solver_type', 'final_sigmas_type', 'use_lu_lambdas', 'dynamic_thresholding_ratio', 'timestep_spacing', 'prediction_type', 'lower_order_final', 'sample_max_value', 'rescale_betas_zero_snr', 'lambda_min_clipped', 'thresholding', 'euler_at_final', 'use_karras_sigmas', 'solver_order'} was not found in config. Values will be initialized to default values.
# Steps:  90% 1800/2000 [35:29<03:29,  1.05s/it, loss=0.166, lr=0.0001]11/06/2024 12:37:21 - INFO - accelerate.accelerator - Saving current state to /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-1800
# 11/06/2024 12:37:22 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-1800/model.safetensors
# 11/06/2024 12:37:23 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-1800/optimizer.bin
# 11/06/2024 12:37:23 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-1800/scheduler.bin
# 11/06/2024 12:37:23 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-1800/sampler.bin
# 11/06/2024 12:37:23 - INFO - accelerate.checkpointing - Gradient scaler state saved in /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-1800/scaler.pt
# 11/06/2024 12:37:23 - INFO - accelerate.checkpointing - Random states saved in /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-1800/random_states_0.pkl
# 11/06/2024 12:37:23 - INFO - __main__ - Saved state to /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-1800
# 11/06/2024 12:37:23 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/6 [00:00<?, ?it/s]Loaded feature_extractor as CLIPFeatureExtractor from `feature_extractor` subfolder of benjamin-paine/stable-diffusion-v1-5.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of benjamin-paine/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 6/6 [00:00<00:00, 1833.84it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# {'variance_type', 'algorithm_type', 'use_beta_sigmas', 'use_exponential_sigmas', 'solver_type', 'final_sigmas_type', 'use_lu_lambdas', 'dynamic_thresholding_ratio', 'timestep_spacing', 'prediction_type', 'lower_order_final', 'sample_max_value', 'rescale_betas_zero_snr', 'lambda_min_clipped', 'thresholding', 'euler_at_final', 'use_karras_sigmas', 'solver_order'} was not found in config. Values will be initialized to default values.
# Steps:  95% 1900/2000 [37:29<01:44,  1.04s/it, loss=0.225, lr=0.0001]11/06/2024 12:39:20 - INFO - accelerate.accelerator - Saving current state to /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-1900
# 11/06/2024 12:39:22 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-1900/model.safetensors
# 11/06/2024 12:39:22 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-1900/optimizer.bin
# 11/06/2024 12:39:22 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-1900/scheduler.bin
# 11/06/2024 12:39:22 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-1900/sampler.bin
# 11/06/2024 12:39:22 - INFO - accelerate.checkpointing - Gradient scaler state saved in /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-1900/scaler.pt
# 11/06/2024 12:39:22 - INFO - accelerate.checkpointing - Random states saved in /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-1900/random_states_0.pkl
# 11/06/2024 12:39:22 - INFO - __main__ - Saved state to /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-1900
# 11/06/2024 12:39:22 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/6 [00:00<?, ?it/s]Loaded feature_extractor as CLIPFeatureExtractor from `feature_extractor` subfolder of benjamin-paine/stable-diffusion-v1-5.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of benjamin-paine/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 6/6 [00:00<00:00, 1829.44it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# {'variance_type', 'algorithm_type', 'use_beta_sigmas', 'use_exponential_sigmas', 'solver_type', 'final_sigmas_type', 'use_lu_lambdas', 'dynamic_thresholding_ratio', 'timestep_spacing', 'prediction_type', 'lower_order_final', 'sample_max_value', 'rescale_betas_zero_snr', 'lambda_min_clipped', 'thresholding', 'euler_at_final', 'use_karras_sigmas', 'solver_order'} was not found in config. Values will be initialized to default values.
# Steps: 100% 2000/2000 [39:27<00:00,  1.20it/s, loss=0.514, lr=0.0001]11/06/2024 12:41:18 - INFO - __main__ - Saving embeddings
# 11/06/2024 12:41:18 - INFO - accelerate.accelerator - Saving current state to /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-2000
# 11/06/2024 12:41:20 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-2000/model.safetensors
# 11/06/2024 12:41:21 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-2000/optimizer.bin
# 11/06/2024 12:41:21 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-2000/scheduler.bin
# 11/06/2024 12:41:21 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-2000/sampler.bin
# 11/06/2024 12:41:21 - INFO - accelerate.checkpointing - Gradient scaler state saved in /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-2000/scaler.pt
# 11/06/2024 12:41:21 - INFO - accelerate.checkpointing - Random states saved in /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-2000/random_states_0.pkl
# 11/06/2024 12:41:21 - INFO - __main__ - Saved state to /content/drive/My Drive/results/textinv/SDv1.5/nils/checkpoint-2000
# 11/06/2024 12:41:21 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/6 [00:00<?, ?it/s]Loaded feature_extractor as CLIPFeatureExtractor from `feature_extractor` subfolder of benjamin-paine/stable-diffusion-v1-5.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of benjamin-paine/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 6/6 [00:00<00:00, 1695.70it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# {'variance_type', 'algorithm_type', 'use_beta_sigmas', 'use_exponential_sigmas', 'solver_type', 'final_sigmas_type', 'use_lu_lambdas', 'dynamic_thresholding_ratio', 'timestep_spacing', 'prediction_type', 'lower_order_final', 'sample_max_value', 'rescale_betas_zero_snr', 'lambda_min_clipped', 'thresholding', 'euler_at_final', 'use_karras_sigmas', 'solver_order'} was not found in config. Values will be initialized to default values.
# Steps: 100% 2000/2000 [39:38<00:00,  1.20it/s, loss=0.0361, lr=0.0001]11/06/2024 12:41:30 - INFO - __main__ - Saving embeddings
# wandb: 29.341 MB of 29.341 MB uploaded
# wandb: 29.341 MB of 29.341 MB uploaded
# wandb:
# wandb: 29.341 MB of 29.341 MB uploaded
# wandb:
# wandb: Run history:
# wandb: loss ▂▃▁▂▁▂▃▁▁▅▆▂█▅▁▂▃▄▂▃▃▃▂▂▄▅▄▆▃▅▃▃▃▅▂▁▆▂▂▆
# wandb:   lr ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb: loss 0.03607
# wandb:   lr 0.0001
# wandb:
# wandb: 🚀 View run dainty-pine-92 at: https://wandb.ai/lnikolei-university-of-cologne/textual_inversion/runs/wggjef6k
# wandb: ⭐️ View project at: https://wandb.ai/lnikolei-university-of-cologne/textual_inversion
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 80 other file(s)
# wandb: Find logs at: ./wandb/run-20241106_120150-wggjef6k/logs
# /usr/local/lib/python3.10/dist-packages/wandb/sdk/wandb_run.py:2386: UserWarning: Run (wggjef6k) is finished. The call to `_console_raw_callback` will be ignored. Please make sure that you are using an active run.
#   lambda data: self._console_raw_callback("stderr", data),
# Steps: 100% 2000/2000 [39:42<00:00,  1.19s/it, loss=0.0361, lr=0.0001]
# Removed /content/train_images/nils_1.jpg
# Removed /content/train_images/nils_6.jpg
# Removed /content/train_images/nils_2.jpg
# Removed /content/train_images/nils_7.jpg
# Removed /content/train_images/nils_10.jpg
# Removed /content/train_images/nils_8.jpg
# Removed /content/train_images/nils_9.jpg
# Removed /content/train_images/nils_5.jpg
# Removed /content/train_images/nils_4.jpg
# Removed /content/train_images/nils_3.jpg
# Directory /content/train_images has been emptied.

# %% [markdown]
# ## Training Text Inversion Embed (SDXL)

# %%
# Check if the MODEL_NAME is set correctly
if os.environ.get('MODEL_NAME') == 'stabilityai/stable-diffusion-xl-base-1.0':
    # Define the parameters for the training script
    train_params = {
        "pretrained_model_name_or_path": os.environ.get('MODEL_NAME'),
        "train_data_dir": os.environ.get('TRAIN_DIR'),
        "learnable_property": "object",
        "placeholder_token": os.environ.get('PLACEHOLDER_TOKEN'),
        "initializer_token": os.environ.get('INITIALIZER_TOKEN'),
        "resolution": os.environ.get('RESOLUTION'),
        "train_batch_size": 4,
        "num_vectors": 2,
        "gradient_accumulation_steps": 1,
        "max_train_steps": 5000,
        "learning_rate": 5e-03,
        "lr_scheduler": "cosine",
        "lr_warmup_steps": 0,
        "validation_prompt": os.environ.get('VALID_PROMPT'),
        "validation_steps":100,
        "output_dir": os.environ.get('OUTPUT_DIR'),
        "mixed_precision": "bf16",
        "checkpointing_steps": 500,
        "report_to": "wandb",
        "seed": 42,
    }

    Save the parameters to a text file
    params_file = os.path.join(os.environ.get('OUTPUT_DIR'), "training_params.txt")
    with open(params_file, "w") as f:
        for key, value in train_params.items():
            f.write(f"{key}: {value}\n")

    # Construct the command to run the training script
    # !accelerate launch textual_inversion_sdxl.py \
        --pretrained_model_name_or_path="{train_params['pretrained_model_name_or_path']}"  \
        --output_dir="{train_params['output_dir']}" \
        --train_data_dir="{train_params['train_data_dir']}" \
        --resolution={train_params['resolution']} \
        --learnable_property="{train_params['learnable_property']}" \
        --initializer_token="{train_params['initializer_token']}" \
        --placeholder_token="{train_params['placeholder_token']}" \
        --train_batch_size="{train_params['train_batch_size']}" \
        --gradient_accumulation_steps={train_params['gradient_accumulation_steps']} \
        --num_vectors={train_params['num_vectors']} \
        --resume_from_checkpoint="latest" \
        --max_train_steps={train_params['max_train_steps']} \
        --checkpointing_steps={train_params['checkpointing_steps']} \
        --mixed_precision="{train_params['mixed_precision']}" \
        --learning_rate={train_params['learning_rate']} --lr_scheduler="{train_params['lr_scheduler']}" --lr_warmup_steps={train_params['lr_warmup_steps']} \
        --validation_steps={train_params['validation_steps']} --validation_prompt="{train_params['validation_prompt']}" --report_to="{train_params['report_to']}" \
        --seed={train_params['seed']}
else:
    print("Cannot run training script. Environment variable MODEL_NAME is not set correctly. Set MODEL_NAME correctly or use appropriate training script.")
# Out:
# 2024-10-31 22:16:04.485693: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-31 22:16:04.506770: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-31 22:16:04.513214: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-31 22:16:05.836010: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 10/31/2024 22:16:07 - INFO - __main__ - Distributed environment: NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: bf16
#
# {'clip_sample_range', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# {'mid_block_add_attention', 'latents_mean', 'use_quant_conv', 'use_post_quant_conv', 'latents_std', 'shift_factor'} was not found in config. Values will be initialized to default values.
# {'attention_type', 'reverse_transformer_layers_per_block', 'dropout'} was not found in config. Values will be initialized to default values.
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: lnikolei (lnikolei-university-of-cologne). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.5
# wandb: Run data is saved locally in /content/wandb/run-20241031_221619-krwatho5
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run somber-vampire-79
# wandb: ⭐️ View project at https://wandb.ai/lnikolei-university-of-cologne/textual_inversion
# wandb: 🚀 View run at https://wandb.ai/lnikolei-university-of-cologne/textual_inversion/runs/krwatho5
# 10/31/2024 22:16:20 - INFO - __main__ - ***** Running training *****
# 10/31/2024 22:16:20 - INFO - __main__ -   Num examples = 1500
# 10/31/2024 22:16:20 - INFO - __main__ -   Num Epochs = 14
# 10/31/2024 22:16:20 - INFO - __main__ -   Instantaneous batch size per device = 4
# 10/31/2024 22:16:20 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 4
# 10/31/2024 22:16:20 - INFO - __main__ -   Gradient Accumulation steps = 1
# 10/31/2024 22:16:20 - INFO - __main__ -   Total optimization steps = 5000
# Checkpoint 'latest' does not exist. Starting a new training run.
# Steps:   0% 0/5000 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:825: UserWarning: cuDNN SDPA backward got grad_output.strides() != output.strides(), attempting to materialize a grad_output with matching strides... (Triggered internally at ../aten/src/ATen/native/cudnn/MHA.cpp:674.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Steps:   2% 100/5000 [01:38<1:13:01,  1.12it/s, loss=0.165, lr=0.003]10/31/2024 22:17:59 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 843.56it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:   4% 200/5000 [03:53<1:08:05,  1.17it/s, loss=0.0737, lr=0.00299]10/31/2024 22:20:14 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2144.95it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:   6% 300/5000 [06:05<1:10:47,  1.11it/s, loss=0.125, lr=0.00297]10/31/2024 22:22:26 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2135.13it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:   8% 400/5000 [08:20<1:21:50,  1.07s/it, loss=0.0547, lr=0.00295]10/31/2024 22:24:41 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2038.76it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  10% 500/5000 [10:31<1:12:35,  1.03it/s, loss=0.0719, lr=0.00293]10/31/2024 22:26:52 - INFO - __main__ - Saving embeddings
# 10/31/2024 22:26:52 - INFO - __main__ - Saving embeddings
# 10/31/2024 22:26:52 - INFO - accelerate.accelerator - Saving current state to /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-500
# 10/31/2024 22:26:53 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-500/model.safetensors
# 10/31/2024 22:27:00 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-500/model_1.safetensors
# 10/31/2024 22:27:01 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-500/optimizer.bin
# 10/31/2024 22:27:01 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-500/scheduler.bin
# 10/31/2024 22:27:01 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-500/sampler.bin
# 10/31/2024 22:27:01 - INFO - accelerate.checkpointing - Random states saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-500/random_states_0.pkl
# 10/31/2024 22:27:01 - INFO - __main__ - Saved state to /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-500
# 10/31/2024 22:27:01 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2159.47it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  12% 600/5000 [12:54<1:04:20,  1.14it/s, loss=0.0308, lr=0.0029]10/31/2024 22:29:15 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2189.91it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  14% 700/5000 [15:08<1:01:10,  1.17it/s, loss=0.0932, lr=0.00286]10/31/2024 22:31:29 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2159.94it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  16% 800/5000 [17:22<1:00:02,  1.17it/s, loss=0.148, lr=0.00281]10/31/2024 22:33:43 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2027.77it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  18% 900/5000 [19:37<1:09:05,  1.01s/it, loss=0.158, lr=0.00277]10/31/2024 22:35:58 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2190.24it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  20% 1000/5000 [21:50<57:34,  1.16it/s, loss=0.104, lr=0.00271]10/31/2024 22:38:11 - INFO - __main__ - Saving embeddings
# 10/31/2024 22:38:11 - INFO - __main__ - Saving embeddings
# 10/31/2024 22:38:11 - INFO - accelerate.accelerator - Saving current state to /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-1000
# 10/31/2024 22:38:12 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-1000/model.safetensors
# 10/31/2024 22:38:17 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-1000/model_1.safetensors
# 10/31/2024 22:38:18 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-1000/optimizer.bin
# 10/31/2024 22:38:18 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-1000/scheduler.bin
# 10/31/2024 22:38:18 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-1000/sampler.bin
# 10/31/2024 22:38:18 - INFO - accelerate.checkpointing - Random states saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-1000/random_states_0.pkl
# 10/31/2024 22:38:18 - INFO - __main__ - Saved state to /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-1000
# 10/31/2024 22:38:18 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2116.50it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  22% 1100/5000 [24:09<56:41,  1.15it/s, loss=0.0675, lr=0.00266]10/31/2024 22:40:30 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2183.07it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  24% 1200/5000 [26:22<58:42,  1.08it/s, loss=0.173, lr=0.00259]10/31/2024 22:42:43 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 1785.57it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  26% 1300/5000 [28:36<55:30,  1.11it/s, loss=0.208, lr=0.00253]10/31/2024 22:44:57 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2080.36it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  28% 1400/5000 [30:50<54:17,  1.11it/s, loss=0.105, lr=0.00246]10/31/2024 22:47:10 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2065.14it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  30% 1500/5000 [33:03<52:12,  1.12it/s, loss=0.119, lr=0.00238]10/31/2024 22:49:24 - INFO - __main__ - Saving embeddings
# 10/31/2024 22:49:24 - INFO - __main__ - Saving embeddings
# 10/31/2024 22:49:24 - INFO - accelerate.accelerator - Saving current state to /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-1500
# 10/31/2024 22:49:26 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-1500/model.safetensors
# 10/31/2024 22:49:30 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-1500/model_1.safetensors
# 10/31/2024 22:49:32 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-1500/optimizer.bin
# 10/31/2024 22:49:32 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-1500/scheduler.bin
# 10/31/2024 22:49:32 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-1500/sampler.bin
# 10/31/2024 22:49:32 - INFO - accelerate.checkpointing - Random states saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-1500/random_states_0.pkl
# 10/31/2024 22:49:32 - INFO - __main__ - Saved state to /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-1500
# 10/31/2024 22:49:32 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 1708.57it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  32% 1600/5000 [35:25<49:06,  1.15it/s, loss=0.103, lr=0.0023]10/31/2024 22:51:46 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2081.10it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  34% 1700/5000 [37:38<50:59,  1.08it/s, loss=0.138, lr=0.00222]10/31/2024 22:53:59 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2058.34it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  36% 1800/5000 [39:51<47:13,  1.13it/s, loss=0.169, lr=0.00214]10/31/2024 22:56:12 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2213.85it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  38% 1900/5000 [42:05<44:32,  1.16it/s, loss=0.204, lr=0.00205]10/31/2024 22:58:26 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2142.29it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  40% 2000/5000 [44:19<43:12,  1.16it/s, loss=0.273, lr=0.00196]10/31/2024 23:00:39 - INFO - __main__ - Saving embeddings
# 10/31/2024 23:00:39 - INFO - __main__ - Saving embeddings
# 10/31/2024 23:00:39 - INFO - accelerate.accelerator - Saving current state to /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-2000
# 10/31/2024 23:00:41 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-2000/model.safetensors
# 10/31/2024 23:00:45 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-2000/model_1.safetensors
# 10/31/2024 23:00:47 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-2000/optimizer.bin
# 10/31/2024 23:00:47 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-2000/scheduler.bin
# 10/31/2024 23:00:47 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-2000/sampler.bin
# 10/31/2024 23:00:47 - INFO - accelerate.checkpointing - Random states saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-2000/random_states_0.pkl
# 10/31/2024 23:00:47 - INFO - __main__ - Saved state to /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-2000
# 10/31/2024 23:00:47 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2119.71it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  42% 2100/5000 [46:38<41:04,  1.18it/s, loss=0.294, lr=0.00187]10/31/2024 23:02:58 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2065.43it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  44% 2200/5000 [48:51<42:51,  1.09it/s, loss=0.0506, lr=0.00178]10/31/2024 23:05:12 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2128.01it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  46% 2300/5000 [51:05<43:01,  1.05it/s, loss=0.219, lr=0.00169]10/31/2024 23:07:25 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2162.65it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  48% 2400/5000 [53:17<40:06,  1.08it/s, loss=0.182, lr=0.0016]10/31/2024 23:09:38 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2097.75it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  50% 2500/5000 [55:31<35:30,  1.17it/s, loss=0.116, lr=0.0015]10/31/2024 23:11:52 - INFO - __main__ - Saving embeddings
# 10/31/2024 23:11:52 - INFO - __main__ - Saving embeddings
# 10/31/2024 23:11:52 - INFO - accelerate.accelerator - Saving current state to /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-2500
# 10/31/2024 23:11:53 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-2500/model.safetensors
# 10/31/2024 23:11:59 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-2500/model_1.safetensors
# 10/31/2024 23:12:00 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-2500/optimizer.bin
# 10/31/2024 23:12:01 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-2500/scheduler.bin
# 10/31/2024 23:12:01 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-2500/sampler.bin
# 10/31/2024 23:12:01 - INFO - accelerate.checkpointing - Random states saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-2500/random_states_0.pkl
# 10/31/2024 23:12:01 - INFO - __main__ - Saved state to /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-2500
# 10/31/2024 23:12:01 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2198.60it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  52% 2600/5000 [57:52<38:56,  1.03it/s, loss=0.129, lr=0.00141]10/31/2024 23:14:13 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2079.33it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  54% 2700/5000 [1:00:05<32:27,  1.18it/s, loss=0.0939, lr=0.00131]10/31/2024 23:16:26 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2138.08it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  56% 2800/5000 [1:02:18<34:05,  1.08it/s, loss=0.0375, lr=0.00122]10/31/2024 23:18:39 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2135.75it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  58% 2900/5000 [1:04:33<32:20,  1.08it/s, loss=0.188, lr=0.00113]10/31/2024 23:20:54 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2083.31it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  60% 3000/5000 [1:06:45<27:47,  1.20it/s, loss=0.158, lr=0.00104]10/31/2024 23:23:06 - INFO - __main__ - Saving embeddings
# 10/31/2024 23:23:06 - INFO - __main__ - Saving embeddings
# 10/31/2024 23:23:06 - INFO - accelerate.accelerator - Saving current state to /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-3000
# 10/31/2024 23:23:07 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-3000/model.safetensors
# 10/31/2024 23:23:12 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-3000/model_1.safetensors
# 10/31/2024 23:23:14 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-3000/optimizer.bin
# 10/31/2024 23:23:14 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-3000/scheduler.bin
# 10/31/2024 23:23:14 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-3000/sampler.bin
# 10/31/2024 23:23:14 - INFO - accelerate.checkpointing - Random states saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-3000/random_states_0.pkl
# 10/31/2024 23:23:14 - INFO - __main__ - Saved state to /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-3000
# 10/31/2024 23:23:14 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2127.39it/s]
# ...
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2078.59it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  86% 4300/5000 [1:36:03<10:07,  1.15it/s, loss=0.13, lr=0.000143]10/31/2024 23:52:24 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2078.30it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  88% 4400/5000 [1:38:16<09:10,  1.09it/s, loss=0.0396, lr=0.000106]10/31/2024 23:54:37 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2127.39it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  90% 4500/5000 [1:40:31<07:24,  1.13it/s, loss=0.00882, lr=7.37e-5]10/31/2024 23:56:52 - INFO - __main__ - Saving embeddings
# 10/31/2024 23:56:52 - INFO - __main__ - Saving embeddings
# 10/31/2024 23:56:52 - INFO - accelerate.accelerator - Saving current state to /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-4500
# 10/31/2024 23:56:53 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-4500/model.safetensors
# 10/31/2024 23:57:00 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-4500/model_1.safetensors
# 10/31/2024 23:57:01 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-4500/optimizer.bin
# 10/31/2024 23:57:01 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-4500/scheduler.bin
# 10/31/2024 23:57:01 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-4500/sampler.bin
# 10/31/2024 23:57:03 - INFO - accelerate.checkpointing - Random states saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-4500/random_states_0.pkl
# 10/31/2024 23:57:03 - INFO - __main__ - Saved state to /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-4500
# 10/31/2024 23:57:03 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 1988.36it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  92% 4600/5000 [1:42:55<06:04,  1.10it/s, loss=0.251, lr=4.74e-5]10/31/2024 23:59:16 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2104.97it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  94% 4700/5000 [1:45:10<05:03,  1.01s/it, loss=0.147, lr=2.67e-5]11/01/2024 00:01:31 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 1964.28it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  96% 4800/5000 [1:47:23<03:04,  1.09it/s, loss=0.0835, lr=1.19e-5]11/01/2024 00:03:44 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2074.63it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps:  98% 4900/5000 [1:49:38<01:26,  1.15it/s, loss=0.0733, lr=3.02e-6]11/01/2024 00:05:59 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2052.73it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps: 100% 5000/5000 [1:51:52<00:00,  1.17it/s, loss=0.0604, lr=2.96e-10]11/01/2024 00:08:12 - INFO - __main__ - Saving embeddings
# 11/01/2024 00:08:12 - INFO - __main__ - Saving embeddings
# 11/01/2024 00:08:13 - INFO - accelerate.accelerator - Saving current state to /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-5000
# 11/01/2024 00:08:14 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-5000/model.safetensors
# 11/01/2024 00:08:18 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-5000/model_1.safetensors
# 11/01/2024 00:08:20 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-5000/optimizer.bin
# 11/01/2024 00:08:20 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-5000/scheduler.bin
# 11/01/2024 00:08:20 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-5000/sampler.bin
# 11/01/2024 00:08:20 - INFO - accelerate.checkpointing - Random states saved in /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-5000/random_states_0.pkl
# 11/01/2024 00:08:20 - INFO - __main__ - Saved state to /content/drive/MyDrive/results/archive/sdxl_leander_27/checkpoint-5000
# 11/01/2024 00:08:20 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2113.15it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# Steps: 100% 5000/5000 [1:52:42<00:00,  1.17it/s, loss=0.103, lr=0]        11/01/2024 00:09:03 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'sigma_max', 'use_beta_sigmas', 'final_sigmas_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'sigma_min', 'timestep_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 1877.97it/s]
# {'solver_order', 'euler_at_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_beta_sigmas', 'algorithm_type', 'lower_order_final', 'final_sigmas_type', 'solver_type', 'use_exponential_sigmas', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# 11/01/2024 00:09:45 - INFO - __main__ - Saving embeddings
# 11/01/2024 00:09:45 - INFO - __main__ - Saving embeddings
# wandb: 264.774 MB of 268.826 MB uploaded
# wandb: 264.774 MB of 268.826 MB uploaded
# wandb:
# wandb: 264.774 MB of 268.826 MB uploaded
# wandb:
# wandb: Run history:
# wandb: loss ▄▅▂▆▃▂▄▁▇▆▅▃▆▄▆▄▃▇▃▄▂▄█▄▅▅▃▅▂▃▃▃▆▆▇▅▃▅▆▁
# wandb:   lr ██████████▇▇▇▆▆▅▅▅▅▅▄▄▃▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb: loss 0.10335
# wandb:   lr 0
# wandb:
# wandb: 🚀 View run somber-vampire-79 at: https://wandb.ai/lnikolei-university-of-cologne/textual_inversion/runs/krwatho5
# wandb: ⭐️ View project at: https://wandb.ai/lnikolei-university-of-cologne/textual_inversion
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 204 other file(s)
# wandb: Find logs at: ./wandb/run-20241031_221619-krwatho5/logs
# /usr/local/lib/python3.10/dist-packages/wandb/sdk/wandb_run.py:2386: UserWarning: Run (krwatho5) is finished. The call to `_console_raw_callback` will be ignored. Please make sure that you are using an active run.
#   lambda data: self._console_raw_callback("stderr", data),
# Steps: 100% 5000/5000 [1:53:28<00:00,  1.36s/it, loss=0.103, lr=0]

# %% [markdown]
# ## Training Loop Textual Inversion (SDXL)

# %%
for subject in subject_list:
  prep_utils.empty_directory(train_directory) # empties train_directory to prepare for training the next subject

  training_subject = subject

  prep_utils.setup_training_environment(train_directory, results_dir, training_model, training_method, training_subject)
  images = prep_utils.load_images(base_dir, training_subject)
  prep_utils.move_images(training_subject, images, train_directory)

  if os.environ.get('MODEL_NAME') == 'stabilityai/stable-diffusion-xl-base-1.0':
  # Check if the MODEL_NAME is set correctly
    train_params = {
            "pretrained_model_name_or_path": os.environ.get('MODEL_NAME'),
            "train_data_dir": os.environ.get('TRAIN_DIR'),
            "learnable_property": "object",
            "placeholder_token": os.environ.get('PLACEHOLDER_TOKEN'),
            "initializer_token": os.environ.get('INITIALIZER_TOKEN'),
            "resolution": os.environ.get('RESOLUTION'),
            "train_batch_size": 4,
            "num_vectors": 2,
            "gradient_accumulation_steps": 1,
            "max_train_steps": 5000,
            "learning_rate": 5e-03,
            "lr_scheduler": "cosine",
            "lr_warmup_steps": 0,
            "validation_prompt": os.environ.get('VALID_PROMPT'),
            "validation_steps":100,
            "output_dir": os.environ.get('OUTPUT_DIR'),
            "mixed_precision": "bf16",
            "checkpointing_steps": 500,
            "report_to": "wandb",
            "seed": 42,
      }

      # Save the parameters to a text file
    params_file = os.path.join(os.environ.get('OUTPUT_DIR'), "training_params.txt")
    with open(params_file, "w") as f:
        for key, value in train_params.items():
            f.write(f"{key}: {value}\n")

    # Construct the command to run the training script
    # !accelerate launch textual_inversion_sdxl.py \
        --pretrained_model_name_or_path="{train_params['pretrained_model_name_or_path']}"  \
        --output_dir="{train_params['output_dir']}" \
        --train_data_dir="{train_params['train_data_dir']}" \
        --resolution={train_params['resolution']} \
        --learnable_property="{train_params['learnable_property']}" \
        --initializer_token="{train_params['initializer_token']}" \
        --placeholder_token="{train_params['placeholder_token']}" \
        --train_batch_size="{train_params['train_batch_size']}" \
        --gradient_accumulation_steps={train_params['gradient_accumulation_steps']} \
        --num_vectors={train_params['num_vectors']} \
        --resume_from_checkpoint="latest" \
        --max_train_steps={train_params['max_train_steps']} \
        --checkpointing_steps={train_params['checkpointing_steps']} \
        --mixed_precision="{train_params['mixed_precision']}" \
        --learning_rate={train_params['learning_rate']} --lr_scheduler="{train_params['lr_scheduler']}" --lr_warmup_steps={train_params['lr_warmup_steps']} \
        --validation_steps={train_params['validation_steps']} --validation_prompt="{train_params['validation_prompt']}" --report_to="{train_params['report_to']}" \
        --seed={train_params['seed']}
  else:
    print("Cannot run training script. Environment variable MODEL_NAME is not set correctly. Set MODEL_NAME correctly or use appropriate training script.")

  prep_utils.empty_directory(train_directory) # empties train_directory to prepare for training of the next subject
# Out:
# Directory does not exist: /content/train_images
# Saved /content/train_images/patrick_1.jpg
# Saved /content/train_images/patrick_2.jpg
# Saved /content/train_images/patrick_3.jpg
# Saved /content/train_images/patrick_4.jpg
# Saved /content/train_images/patrick_5.jpg
# Saved /content/train_images/patrick_6.jpg
# Saved /content/train_images/patrick_7.jpg
# Saved /content/train_images/patrick_8.jpg
# Saved /content/train_images/patrick_9.jpg
# Saved /content/train_images/patrick_10.jpg
# 2024-11-07 11:39:21.108113: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-07 11:39:21.128940: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-07 11:39:21.135224: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-07 11:39:22.347075: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 11/07/2024 11:39:24 - INFO - __main__ - Distributed environment: NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: bf16
#
# tokenizer/tokenizer_config.json: 100% 737/737 [00:00<00:00, 5.41MB/s]
# tokenizer/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 4.45MB/s]
# tokenizer/merges.txt: 100% 525k/525k [00:00<00:00, 2.42MB/s]
# tokenizer/special_tokens_map.json: 100% 472/472 [00:00<00:00, 3.71MB/s]
# tokenizer_2/tokenizer_config.json: 100% 725/725 [00:00<00:00, 4.74MB/s]
# tokenizer_2/special_tokens_map.json: 100% 460/460 [00:00<00:00, 3.49MB/s]
# scheduler/scheduler_config.json: 100% 479/479 [00:00<00:00, 2.68MB/s]
# {'clip_sample_range', 'thresholding', 'variance_type', 'dynamic_thresholding_ratio', 'rescale_betas_zero_snr'} was not found in config. Values will be initialized to default values.
# text_encoder/config.json: 100% 565/565 [00:00<00:00, 1.15MB/s]
# model.safetensors: 100% 492M/492M [00:02<00:00, 233MB/s]
# text_encoder_2/config.json: 100% 575/575 [00:00<00:00, 4.30MB/s]
# model.safetensors: 100% 2.78G/2.78G [00:12<00:00, 222MB/s]
# vae/config.json: 100% 642/642 [00:00<00:00, 4.91MB/s]
# diffusion_pytorch_model.safetensors: 100% 335M/335M [00:01<00:00, 229MB/s]
# {'use_quant_conv', 'latents_std', 'mid_block_add_attention', 'shift_factor', 'use_post_quant_conv', 'latents_mean'} was not found in config. Values will be initialized to default values.
# unet/config.json: 100% 1.68k/1.68k [00:00<00:00, 12.5MB/s]
# diffusion_pytorch_model.safetensors: 100% 10.3G/10.3G [00:54<00:00, 188MB/s]
# {'attention_type', 'reverse_transformer_layers_per_block', 'dropout'} was not found in config. Values will be initialized to default values.
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: lnikolei (lnikolei-university-of-cologne). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.5
# wandb: Run data is saved locally in /content/wandb/run-20241107_114053-zh0itmzd
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run iconic-brook-102
# wandb: ⭐️ View project at https://wandb.ai/lnikolei-university-of-cologne/textual_inversion
# wandb: 🚀 View run at https://wandb.ai/lnikolei-university-of-cologne/textual_inversion/runs/zh0itmzd
# 11/07/2024 11:40:55 - INFO - __main__ - ***** Running training *****
# 11/07/2024 11:40:55 - INFO - __main__ -   Num examples = 1000
# 11/07/2024 11:40:55 - INFO - __main__ -   Num Epochs = 20
# 11/07/2024 11:40:55 - INFO - __main__ -   Instantaneous batch size per device = 4
# 11/07/2024 11:40:55 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 4
# 11/07/2024 11:40:55 - INFO - __main__ -   Gradient Accumulation steps = 1
# 11/07/2024 11:40:55 - INFO - __main__ -   Total optimization steps = 5000
# Resuming from checkpoint checkpoint-2000
# 11/07/2024 11:40:55 - INFO - accelerate.accelerator - Loading states from /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-2000
# 11/07/2024 11:41:43 - INFO - accelerate.checkpointing - All model weights loaded successfully
# /usr/local/lib/python3.10/dist-packages/accelerate/checkpointing.py:228: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   optimizer_state = torch.load(input_optimizer_file, map_location=map_location)
# 11/07/2024 11:41:48 - INFO - accelerate.checkpointing - All optimizer states loaded successfully
# /usr/local/lib/python3.10/dist-packages/accelerate/checkpointing.py:236: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   scheduler.load_state_dict(torch.load(input_scheduler_file))
# 11/07/2024 11:41:49 - INFO - accelerate.checkpointing - All scheduler states loaded successfully
# 11/07/2024 11:41:49 - INFO - accelerate.checkpointing - All dataloader sampler states loaded successfully
# /usr/local/lib/python3.10/dist-packages/accelerate/checkpointing.py:265: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   states = torch.load(input_dir.joinpath(f"{RNG_STATE_NAME}_{process_index}.pkl"))
# 11/07/2024 11:41:50 - INFO - accelerate.checkpointing - All random states loaded successfully
# 11/07/2024 11:41:50 - INFO - accelerate.accelerator - Loading in 0 custom states
# Steps:  40% 2000/5000 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:825: UserWarning: cuDNN SDPA backward got grad_output.strides() != output.strides(), attempting to materialize a grad_output with matching strides... (Triggered internally at ../aten/src/ATen/native/cudnn/MHA.cpp:674.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Steps:  42% 2100/5000 [01:52<48:50,  1.01s/it, loss=0.285, lr=0.00312]11/07/2024 11:43:42 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
#
# model_index.json: 100% 609/609 [00:00<00:00, 1.93MB/s]
#
# Fetching 3 files:   0% 0/3 [00:00<?, ?it/s]
#
# diffusion_pytorch_model.safetensors:   0% 0.00/335M [00:00<?, ?B/s]
#
# diffusion_pytorch_model.safetensors:   3% 10.5M/335M [00:00<00:10, 29.8MB/s]
#
# diffusion_pytorch_model.safetensors:   6% 21.0M/335M [00:00<00:06, 47.1MB/s]
#
# diffusion_pytorch_model.safetensors:   9% 31.5M/335M [00:00<00:04, 60.9MB/s]
#
# diffusion_pytorch_model.safetensors:  16% 52.4M/335M [00:00<00:03, 73.9MB/s]
#
# diffusion_pytorch_model.safetensors:  19% 62.9M/335M [00:00<00:03, 80.3MB/s]
#
# diffusion_pytorch_model.safetensors:  22% 73.4M/335M [00:01<00:03, 85.8MB/s]
#
# diffusion_pytorch_model.safetensors:  28% 94.4M/335M [00:01<00:02, 94.1MB/s]
#
# diffusion_pytorch_model.safetensors:  31% 105M/335M [00:01<00:02, 84.6MB/s]
#
# diffusion_pytorch_model.safetensors:  34% 115M/335M [00:01<00:02, 88.5MB/s]
#
# diffusion_pytorch_model.safetensors:  38% 126M/335M [00:01<00:02, 90.4MB/s]
#
# diffusion_pytorch_model.safetensors:  41% 136M/335M [00:01<00:02, 87.4MB/s]
#
# diffusion_pytorch_model.safetensors:  44% 147M/335M [00:01<00:02, 90.9MB/s]
#
# diffusion_pytorch_model.safetensors:  50% 168M/335M [00:02<00:01, 97.1MB/s]
#
# diffusion_pytorch_model.safetensors:  56% 189M/335M [00:02<00:01, 100MB/s]
#
# diffusion_pytorch_model.safetensors:  60% 199M/335M [00:02<00:01, 95.2MB/s]
#
# diffusion_pytorch_model.safetensors:  63% 210M/335M [00:02<00:01, 91.4MB/s]
#
# diffusion_pytorch_model.safetensors:  69% 231M/335M [00:02<00:01, 96.7MB/s]
#
# diffusion_pytorch_model.safetensors:  72% 241M/335M [00:02<00:01, 91.6MB/s]
#
# diffusion_pytorch_model.safetensors:  75% 252M/335M [00:02<00:00, 92.6MB/s]
#
# diffusion_pytorch_model.safetensors:  78% 262M/335M [00:03<00:00, 94.8MB/s]
#
# diffusion_pytorch_model.safetensors:  85% 283M/335M [00:03<00:00, 99.3MB/s]
#
# diffusion_pytorch_model.safetensors:  88% 294M/335M [00:03<00:00, 99.6MB/s]
#
# diffusion_pytorch_model.safetensors:  91% 304M/335M [00:03<00:00, 87.3MB/s]
#
# diffusion_pytorch_model.safetensors:  94% 315M/335M [00:03<00:00, 89.7MB/s]
#
# diffusion_pytorch_model.safetensors: 100% 335M/335M [00:03<00:00, 87.6MB/s]
#
# Fetching 3 files: 100% 3/3 [00:04<00:00,  1.41s/it]
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'use_exponential_sigmas', 'timestep_type', 'use_beta_sigmas', 'sigma_max', 'rescale_betas_zero_snr', 'sigma_min', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 165.63it/s]
# {'solver_order', 'use_lu_lambdas', 'thresholding', 'lambda_min_clipped', 'use_exponential_sigmas', 'lower_order_final', 'euler_at_final', 'algorithm_type', 'variance_type', 'use_beta_sigmas', 'dynamic_thresholding_ratio', 'solver_type', 'rescale_betas_zero_snr', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Steps:  44% 2200/5000 [04:24<45:44,  1.02it/s, loss=0.0538, lr=0.00297]11/07/2024 11:46:15 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'use_exponential_sigmas', 'timestep_type', 'use_beta_sigmas', 'sigma_max', 'rescale_betas_zero_snr', 'sigma_min', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2232.03it/s]
# {'solver_order', 'use_lu_lambdas', 'thresholding', 'lambda_min_clipped', 'use_exponential_sigmas', 'lower_order_final', 'euler_at_final', 'algorithm_type', 'variance_type', 'use_beta_sigmas', 'dynamic_thresholding_ratio', 'solver_type', 'rescale_betas_zero_snr', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Steps:  46% 2300/5000 [06:49<45:25,  1.01s/it, loss=0.233, lr=0.00281]11/07/2024 11:48:40 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'use_exponential_sigmas', 'timestep_type', 'use_beta_sigmas', 'sigma_max', 'rescale_betas_zero_snr', 'sigma_min', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2233.22it/s]
# {'solver_order', 'use_lu_lambdas', 'thresholding', 'lambda_min_clipped', 'use_exponential_sigmas', 'lower_order_final', 'euler_at_final', 'algorithm_type', 'variance_type', 'use_beta_sigmas', 'dynamic_thresholding_ratio', 'solver_type', 'rescale_betas_zero_snr', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Steps:  48% 2400/5000 [09:14<44:16,  1.02s/it, loss=0.182, lr=0.00266]11/07/2024 11:51:04 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'use_exponential_sigmas', 'timestep_type', 'use_beta_sigmas', 'sigma_max', 'rescale_betas_zero_snr', 'sigma_min', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2175.63it/s]
# {'solver_order', 'use_lu_lambdas', 'thresholding', 'lambda_min_clipped', 'use_exponential_sigmas', 'lower_order_final', 'euler_at_final', 'algorithm_type', 'variance_type', 'use_beta_sigmas', 'dynamic_thresholding_ratio', 'solver_type', 'rescale_betas_zero_snr', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Steps:  50% 2500/5000 [11:39<40:00,  1.04it/s, loss=0.109, lr=0.0025]11/07/2024 11:53:30 - INFO - __main__ - Saving embeddings
# 11/07/2024 11:53:30 - INFO - __main__ - Saving embeddings
# 11/07/2024 11:53:30 - INFO - accelerate.accelerator - Saving current state to /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-2500
# 11/07/2024 11:53:31 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-2500/model.safetensors
# 11/07/2024 11:53:38 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-2500/model_1.safetensors
# 11/07/2024 11:53:40 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-2500/optimizer.bin
# 11/07/2024 11:53:40 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-2500/scheduler.bin
# 11/07/2024 11:53:40 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-2500/sampler.bin
# 11/07/2024 11:53:40 - INFO - accelerate.checkpointing - Random states saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-2500/random_states_0.pkl
# 11/07/2024 11:53:40 - INFO - __main__ - Saved state to /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-2500
# 11/07/2024 11:53:40 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'use_exponential_sigmas', 'timestep_type', 'use_beta_sigmas', 'sigma_max', 'rescale_betas_zero_snr', 'sigma_min', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2007.12it/s]
# {'solver_order', 'use_lu_lambdas', 'thresholding', 'lambda_min_clipped', 'use_exponential_sigmas', 'lower_order_final', 'euler_at_final', 'algorithm_type', 'variance_type', 'use_beta_sigmas', 'dynamic_thresholding_ratio', 'solver_type', 'rescale_betas_zero_snr', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Steps:  52% 2600/5000 [14:14<41:11,  1.03s/it, loss=0.108, lr=0.00234]11/07/2024 11:56:05 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'use_exponential_sigmas', 'timestep_type', 'use_beta_sigmas', 'sigma_max', 'rescale_betas_zero_snr', 'sigma_min', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2227.80it/s]
# {'solver_order', 'use_lu_lambdas', 'thresholding', 'lambda_min_clipped', 'use_exponential_sigmas', 'lower_order_final', 'euler_at_final', 'algorithm_type', 'variance_type', 'use_beta_sigmas', 'dynamic_thresholding_ratio', 'solver_type', 'rescale_betas_zero_snr', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Steps:  54% 2700/5000 [16:41<40:27,  1.06s/it, loss=0.0906, lr=0.00219]11/07/2024 11:58:31 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'use_exponential_sigmas', 'timestep_type', 'use_beta_sigmas', 'sigma_max', 'rescale_betas_zero_snr', 'sigma_min', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2182.75it/s]
# {'solver_order', 'use_lu_lambdas', 'thresholding', 'lambda_min_clipped', 'use_exponential_sigmas', 'lower_order_final', 'euler_at_final', 'algorithm_type', 'variance_type', 'use_beta_sigmas', 'dynamic_thresholding_ratio', 'solver_type', 'rescale_betas_zero_snr', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Steps:  56% 2800/5000 [19:05<38:18,  1.04s/it, loss=0.0303, lr=0.00203]11/07/2024 12:00:56 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'use_exponential_sigmas', 'timestep_type', 'use_beta_sigmas', 'sigma_max', 'rescale_betas_zero_snr', 'sigma_min', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2310.55it/s]
# {'solver_order', 'use_lu_lambdas', 'thresholding', 'lambda_min_clipped', 'use_exponential_sigmas', 'lower_order_final', 'euler_at_final', 'algorithm_type', 'variance_type', 'use_beta_sigmas', 'dynamic_thresholding_ratio', 'solver_type', 'rescale_betas_zero_snr', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Steps:  58% 2900/5000 [21:29<34:59,  1.00it/s, loss=0.198, lr=0.00188]11/07/2024 12:03:20 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'use_exponential_sigmas', 'timestep_type', 'use_beta_sigmas', 'sigma_max', 'rescale_betas_zero_snr', 'sigma_min', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2275.27it/s]
# {'solver_order', 'use_lu_lambdas', 'thresholding', 'lambda_min_clipped', 'use_exponential_sigmas', 'lower_order_final', 'euler_at_final', 'algorithm_type', 'variance_type', 'use_beta_sigmas', 'dynamic_thresholding_ratio', 'solver_type', 'rescale_betas_zero_snr', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Steps:  60% 3000/5000 [23:54<31:45,  1.05it/s, loss=0.136, lr=0.00173]11/07/2024 12:05:45 - INFO - __main__ - Saving embeddings
# 11/07/2024 12:05:45 - INFO - __main__ - Saving embeddings
# 11/07/2024 12:05:45 - INFO - accelerate.accelerator - Saving current state to /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-3000
# 11/07/2024 12:05:46 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-3000/model.safetensors
# 11/07/2024 12:05:51 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-3000/model_1.safetensors
# 11/07/2024 12:05:53 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-3000/optimizer.bin
# 11/07/2024 12:05:53 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-3000/scheduler.bin
# 11/07/2024 12:05:53 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-3000/sampler.bin
# 11/07/2024 12:05:53 - INFO - accelerate.checkpointing - Random states saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-3000/random_states_0.pkl
# 11/07/2024 12:05:53 - INFO - __main__ - Saved state to /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-3000
# 11/07/2024 12:05:53 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'use_exponential_sigmas', 'timestep_type', 'use_beta_sigmas', 'sigma_max', 'rescale_betas_zero_snr', 'sigma_min', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2225.43it/s]
# {'solver_order', 'use_lu_lambdas', 'thresholding', 'lambda_min_clipped', 'use_exponential_sigmas', 'lower_order_final', 'euler_at_final', 'algorithm_type', 'variance_type', 'use_beta_sigmas', 'dynamic_thresholding_ratio', 'solver_type', 'rescale_betas_zero_snr', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Steps:  62% 3100/5000 [26:28<30:52,  1.03it/s, loss=0.13, lr=0.00158]11/07/2024 12:08:19 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'use_exponential_sigmas', 'timestep_type', 'use_beta_sigmas', 'sigma_max', 'rescale_betas_zero_snr', 'sigma_min', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2313.83it/s]
# {'solver_order', 'use_lu_lambdas', 'thresholding', 'lambda_min_clipped', 'use_exponential_sigmas', 'lower_order_final', 'euler_at_final', 'algorithm_type', 'variance_type', 'use_beta_sigmas', 'dynamic_thresholding_ratio', 'solver_type', 'rescale_betas_zero_snr', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Steps:  64% 3200/5000 [28:52<29:10,  1.03it/s, loss=0.098, lr=0.00144]11/07/2024 12:10:43 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'use_exponential_sigmas', 'timestep_type', 'use_beta_sigmas', 'sigma_max', 'rescale_betas_zero_snr', 'sigma_min', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2219.71it/s]
# {'solver_order', 'use_lu_lambdas', 'thresholding', 'lambda_min_clipped', 'use_exponential_sigmas', 'lower_order_final', 'euler_at_final', 'algorithm_type', 'variance_type', 'use_beta_sigmas', 'dynamic_thresholding_ratio', 'solver_type', 'rescale_betas_zero_snr', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Steps:  66% 3300/5000 [31:18<31:27,  1.11s/it, loss=0.0325, lr=0.0013]11/07/2024 12:13:09 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'use_exponential_sigmas', 'timestep_type', 'use_beta_sigmas', 'sigma_max', 'rescale_betas_zero_snr', 'sigma_min', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2227.63it/s]
# {'solver_order', 'use_lu_lambdas', 'thresholding', 'lambda_min_clipped', 'use_exponential_sigmas', 'lower_order_final', 'euler_at_final', 'algorithm_type', 'variance_type', 'use_beta_sigmas', 'dynamic_thresholding_ratio', 'solver_type', 'rescale_betas_zero_snr', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Steps:  68% 3400/5000 [33:42<26:04,  1.02it/s, loss=0.123, lr=0.00116]11/07/2024 12:15:33 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'use_exponential_sigmas', 'timestep_type', 'use_beta_sigmas', 'sigma_max', 'rescale_betas_zero_snr', 'sigma_min', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2270.17it/s]
# {'solver_order', 'use_lu_lambdas', 'thresholding', 'lambda_min_clipped', 'use_exponential_sigmas', 'lower_order_final', 'euler_at_final', 'algorithm_type', 'variance_type', 'use_beta_sigmas', 'dynamic_thresholding_ratio', 'solver_type', 'rescale_betas_zero_snr', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Steps:  70% 3500/5000 [36:06<22:04,  1.13it/s, loss=0.0592, lr=0.00103]11/07/2024 12:17:57 - INFO - __main__ - Saving embeddings
# 11/07/2024 12:17:57 - INFO - __main__ - Saving embeddings
# 11/07/2024 12:17:57 - INFO - accelerate.accelerator - Saving current state to /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-3500
# 11/07/2024 12:17:58 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-3500/model.safetensors
# 11/07/2024 12:18:05 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-3500/model_1.safetensors
# 11/07/2024 12:18:06 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-3500/optimizer.bin
# 11/07/2024 12:18:06 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-3500/scheduler.bin
# 11/07/2024 12:18:06 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-3500/sampler.bin
# 11/07/2024 12:18:06 - INFO - accelerate.checkpointing - Random states saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-3500/random_states_0.pkl
# 11/07/2024 12:18:06 - INFO - __main__ - Saved state to /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-3500
# 11/07/2024 12:18:06 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'use_exponential_sigmas', 'timestep_type', 'use_beta_sigmas', 'sigma_max', 'rescale_betas_zero_snr', 'sigma_min', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 1974.72it/s]
# {'solver_order', 'use_lu_lambdas', 'thresholding', 'lambda_min_clipped', 'use_exponential_sigmas', 'lower_order_final', 'euler_at_final', 'algorithm_type', 'variance_type', 'use_beta_sigmas', 'dynamic_thresholding_ratio', 'solver_type', 'rescale_betas_zero_snr', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Steps:  72% 3600/5000 [38:41<23:33,  1.01s/it, loss=0.17, lr=0.000908]11/07/2024 12:20:31 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'use_exponential_sigmas', 'timestep_type', 'use_beta_sigmas', 'sigma_max', 'rescale_betas_zero_snr', 'sigma_min', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2248.61it/s]
# {'solver_order', 'use_lu_lambdas', 'thresholding', 'lambda_min_clipped', 'use_exponential_sigmas', 'lower_order_final', 'euler_at_final', 'algorithm_type', 'variance_type', 'use_beta_sigmas', 'dynamic_thresholding_ratio', 'solver_type', 'rescale_betas_zero_snr', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Steps:  74% 3700/5000 [41:06<20:14,  1.07it/s, loss=0.158, lr=0.00079]11/07/2024 12:22:57 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'use_exponential_sigmas', 'timestep_type', 'use_beta_sigmas', 'sigma_max', 'rescale_betas_zero_snr', 'sigma_min', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2159.15it/s]
# {'solver_order', 'use_lu_lambdas', 'thresholding', 'lambda_min_clipped', 'use_exponential_sigmas', 'lower_order_final', 'euler_at_final', 'algorithm_type', 'variance_type', 'use_beta_sigmas', 'dynamic_thresholding_ratio', 'solver_type', 'rescale_betas_zero_snr', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Steps:  76% 3800/5000 [43:31<20:45,  1.04s/it, loss=0.195, lr=0.000679]11/07/2024 12:25:21 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'use_exponential_sigmas', 'timestep_type', 'use_beta_sigmas', 'sigma_max', 'rescale_betas_zero_snr', 'sigma_min', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2125.39it/s]
# {'solver_order', 'use_lu_lambdas', 'thresholding', 'lambda_min_clipped', 'use_exponential_sigmas', 'lower_order_final', 'euler_at_final', 'algorithm_type', 'variance_type', 'use_beta_sigmas', 'dynamic_thresholding_ratio', 'solver_type', 'rescale_betas_zero_snr', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Steps:  78% 3900/5000 [45:56<19:43,  1.08s/it, loss=0.115, lr=0.000575]11/07/2024 12:27:47 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'use_exponential_sigmas', 'timestep_type', 'use_beta_sigmas', 'sigma_max', 'rescale_betas_zero_snr', 'sigma_min', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2296.09it/s]
# {'solver_order', 'use_lu_lambdas', 'thresholding', 'lambda_min_clipped', 'use_exponential_sigmas', 'lower_order_final', 'euler_at_final', 'algorithm_type', 'variance_type', 'use_beta_sigmas', 'dynamic_thresholding_ratio', 'solver_type', 'rescale_betas_zero_snr', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Steps:  80% 4000/5000 [48:21<15:36,  1.07it/s, loss=0.0919, lr=0.000478]11/07/2024 12:30:11 - INFO - __main__ - Saving embeddings
# 11/07/2024 12:30:11 - INFO - __main__ - Saving embeddings
# 11/07/2024 12:30:11 - INFO - accelerate.accelerator - Saving current state to /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-4000
# 11/07/2024 12:30:13 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-4000/model.safetensors
# 11/07/2024 12:30:17 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-4000/model_1.safetensors
# 11/07/2024 12:30:18 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-4000/optimizer.bin
# 11/07/2024 12:30:18 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-4000/scheduler.bin
# 11/07/2024 12:30:18 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-4000/sampler.bin
# 11/07/2024 12:30:18 - INFO - accelerate.checkpointing - Random states saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-4000/random_states_0.pkl
# 11/07/2024 12:30:18 - INFO - __main__ - Saved state to /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-4000
# 11/07/2024 12:30:18 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'use_exponential_sigmas', 'timestep_type', 'use_beta_sigmas', 'sigma_max', 'rescale_betas_zero_snr', 'sigma_min', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2288.04it/s]
# {'solver_order', 'use_lu_lambdas', 'thresholding', 'lambda_min_clipped', 'use_exponential_sigmas', 'lower_order_final', 'euler_at_final', 'algorithm_type', 'variance_type', 'use_beta_sigmas', 'dynamic_thresholding_ratio', 'solver_type', 'rescale_betas_zero_snr', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Steps:  82% 4100/5000 [50:52<15:12,  1.01s/it, loss=0.134, lr=0.00039]11/07/2024 12:32:43 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'use_exponential_sigmas', 'timestep_type', 'use_beta_sigmas', 'sigma_max', 'rescale_betas_zero_snr', 'sigma_min', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2255.18it/s]
# {'solver_order', 'use_lu_lambdas', 'thresholding', 'lambda_min_clipped', 'use_exponential_sigmas', 'lower_order_final', 'euler_at_final', 'algorithm_type', 'variance_type', 'use_beta_sigmas', 'dynamic_thresholding_ratio', 'solver_type', 'rescale_betas_zero_snr', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Steps:  84% 4200/5000 [53:18<13:45,  1.03s/it, loss=0.192, lr=0.00031]11/07/2024 12:35:08 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'use_exponential_sigmas', 'timestep_type', 'use_beta_sigmas', 'sigma_max', 'rescale_betas_zero_snr', 'sigma_min', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2154.56it/s]
# {'solver_order', 'use_lu_lambdas', 'thresholding', 'lambda_min_clipped', 'use_exponential_sigmas', 'lower_order_final', 'euler_at_final', 'algorithm_type', 'variance_type', 'use_beta_sigmas', 'dynamic_thresholding_ratio', 'solver_type', 'rescale_betas_zero_snr', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Steps:  86% 4300/5000 [55:43<11:52,  1.02s/it, loss=0.124, lr=0.000239]11/07/2024 12:37:33 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'use_exponential_sigmas', 'timestep_type', 'use_beta_sigmas', 'sigma_max', 'rescale_betas_zero_snr', 'sigma_min', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2167.92it/s]
# {'solver_order', 'use_lu_lambdas', 'thresholding', 'lambda_min_clipped', 'use_exponential_sigmas', 'lower_order_final', 'euler_at_final', 'algorithm_type', 'variance_type', 'use_beta_sigmas', 'dynamic_thresholding_ratio', 'solver_type', 'rescale_betas_zero_snr', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Steps:  88% 4400/5000 [58:08<11:11,  1.12s/it, loss=0.0319, lr=0.000176]11/07/2024 12:39:59 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'use_exponential_sigmas', 'timestep_type', 'use_beta_sigmas', 'sigma_max', 'rescale_betas_zero_snr', 'sigma_min', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2202.06it/s]
# {'solver_order', 'use_lu_lambdas', 'thresholding', 'lambda_min_clipped', 'use_exponential_sigmas', 'lower_order_final', 'euler_at_final', 'algorithm_type', 'variance_type', 'use_beta_sigmas', 'dynamic_thresholding_ratio', 'solver_type', 'rescale_betas_zero_snr', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Steps:  90% 4500/5000 [1:00:32<07:29,  1.11it/s, loss=0.0115, lr=0.000123]11/07/2024 12:42:23 - INFO - __main__ - Saving embeddings
# 11/07/2024 12:42:23 - INFO - __main__ - Saving embeddings
# 11/07/2024 12:42:23 - INFO - accelerate.accelerator - Saving current state to /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-4500
# 11/07/2024 12:42:24 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-4500/model.safetensors
# 11/07/2024 12:42:31 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-4500/model_1.safetensors
# 11/07/2024 12:42:32 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-4500/optimizer.bin
# 11/07/2024 12:42:32 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-4500/scheduler.bin
# 11/07/2024 12:42:32 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-4500/sampler.bin
# 11/07/2024 12:42:32 - INFO - accelerate.checkpointing - Random states saved in /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-4500/random_states_0.pkl
# 11/07/2024 12:42:32 - INFO - __main__ - Saved state to /content/drive/My Drive/results/textinv/SDXL/patrick/checkpoint-4500
# 11/07/2024 12:42:32 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'use_exponential_sigmas', 'timestep_type', 'use_beta_sigmas', 'sigma_max', 'rescale_betas_zero_snr', 'sigma_min', 'final_sigmas_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2200.58it/s]
# ...
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2122.93it/s]
# {'final_sigmas_type', 'dynamic_thresholding_ratio', 'rescale_betas_zero_snr', 'use_exponential_sigmas', 'euler_at_final', 'lambda_min_clipped', 'solver_order', 'variance_type', 'thresholding', 'lower_order_final', 'use_beta_sigmas', 'algorithm_type', 'use_lu_lambdas', 'solver_type'} was not found in config. Values will be initialized to default values.
# Steps:  86% 4300/5000 [1:46:34<12:31,  1.07s/it, loss=0.13, lr=0.000239]11/07/2024 16:45:23 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'image_encoder', 'feature_extractor'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'final_sigmas_type', 'timestep_type', 'rescale_betas_zero_snr', 'use_exponential_sigmas', 'sigma_min', 'sigma_max', 'use_beta_sigmas'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 1880.37it/s]
# {'final_sigmas_type', 'dynamic_thresholding_ratio', 'rescale_betas_zero_snr', 'use_exponential_sigmas', 'euler_at_final', 'lambda_min_clipped', 'solver_order', 'variance_type', 'thresholding', 'lower_order_final', 'use_beta_sigmas', 'algorithm_type', 'use_lu_lambdas', 'solver_type'} was not found in config. Values will be initialized to default values.
# Steps:  88% 4400/5000 [1:49:02<10:46,  1.08s/it, loss=0.0325, lr=0.000176]11/07/2024 16:47:51 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'image_encoder', 'feature_extractor'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'final_sigmas_type', 'timestep_type', 'rescale_betas_zero_snr', 'use_exponential_sigmas', 'sigma_min', 'sigma_max', 'use_beta_sigmas'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 1931.08it/s]
# {'final_sigmas_type', 'dynamic_thresholding_ratio', 'rescale_betas_zero_snr', 'use_exponential_sigmas', 'euler_at_final', 'lambda_min_clipped', 'solver_order', 'variance_type', 'thresholding', 'lower_order_final', 'use_beta_sigmas', 'algorithm_type', 'use_lu_lambdas', 'solver_type'} was not found in config. Values will be initialized to default values.
# Steps:  90% 4500/5000 [1:51:29<07:38,  1.09it/s, loss=0.00987, lr=0.000123]11/07/2024 16:50:18 - INFO - __main__ - Saving embeddings
# 11/07/2024 16:50:18 - INFO - __main__ - Saving embeddings
# 11/07/2024 16:50:18 - INFO - accelerate.accelerator - Saving current state to /content/drive/My Drive/results/textinv/SDXL/nils/checkpoint-4500
# 11/07/2024 16:50:20 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDXL/nils/checkpoint-4500/model.safetensors
# 11/07/2024 16:50:25 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDXL/nils/checkpoint-4500/model_1.safetensors
# 11/07/2024 16:50:27 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/My Drive/results/textinv/SDXL/nils/checkpoint-4500/optimizer.bin
# 11/07/2024 16:50:27 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/My Drive/results/textinv/SDXL/nils/checkpoint-4500/scheduler.bin
# 11/07/2024 16:50:27 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/My Drive/results/textinv/SDXL/nils/checkpoint-4500/sampler.bin
# 11/07/2024 16:50:27 - INFO - accelerate.checkpointing - Random states saved in /content/drive/My Drive/results/textinv/SDXL/nils/checkpoint-4500/random_states_0.pkl
# 11/07/2024 16:50:27 - INFO - __main__ - Saved state to /content/drive/My Drive/results/textinv/SDXL/nils/checkpoint-4500
# 11/07/2024 16:50:27 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'image_encoder', 'feature_extractor'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'final_sigmas_type', 'timestep_type', 'rescale_betas_zero_snr', 'use_exponential_sigmas', 'sigma_min', 'sigma_max', 'use_beta_sigmas'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2102.86it/s]
# {'final_sigmas_type', 'dynamic_thresholding_ratio', 'rescale_betas_zero_snr', 'use_exponential_sigmas', 'euler_at_final', 'lambda_min_clipped', 'solver_order', 'variance_type', 'thresholding', 'lower_order_final', 'use_beta_sigmas', 'algorithm_type', 'use_lu_lambdas', 'solver_type'} was not found in config. Values will be initialized to default values.
# Steps:  92% 4600/5000 [1:54:06<07:22,  1.11s/it, loss=0.261, lr=7.89e-5]11/07/2024 16:52:55 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'image_encoder', 'feature_extractor'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'final_sigmas_type', 'timestep_type', 'rescale_betas_zero_snr', 'use_exponential_sigmas', 'sigma_min', 'sigma_max', 'use_beta_sigmas'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2226.11it/s]
# {'final_sigmas_type', 'dynamic_thresholding_ratio', 'rescale_betas_zero_snr', 'use_exponential_sigmas', 'euler_at_final', 'lambda_min_clipped', 'solver_order', 'variance_type', 'thresholding', 'lower_order_final', 'use_beta_sigmas', 'algorithm_type', 'use_lu_lambdas', 'solver_type'} was not found in config. Values will be initialized to default values.
# Steps:  94% 4700/5000 [1:56:33<05:22,  1.07s/it, loss=0.149, lr=4.46e-5]11/07/2024 16:55:22 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'image_encoder', 'feature_extractor'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'final_sigmas_type', 'timestep_type', 'rescale_betas_zero_snr', 'use_exponential_sigmas', 'sigma_min', 'sigma_max', 'use_beta_sigmas'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2091.48it/s]
# {'final_sigmas_type', 'dynamic_thresholding_ratio', 'rescale_betas_zero_snr', 'use_exponential_sigmas', 'euler_at_final', 'lambda_min_clipped', 'solver_order', 'variance_type', 'thresholding', 'lower_order_final', 'use_beta_sigmas', 'algorithm_type', 'use_lu_lambdas', 'solver_type'} was not found in config. Values will be initialized to default values.
# Steps:  96% 4800/5000 [1:59:02<03:35,  1.08s/it, loss=0.105, lr=1.99e-5]11/07/2024 16:57:51 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'image_encoder', 'feature_extractor'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'final_sigmas_type', 'timestep_type', 'rescale_betas_zero_snr', 'use_exponential_sigmas', 'sigma_min', 'sigma_max', 'use_beta_sigmas'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2287.33it/s]
# {'final_sigmas_type', 'dynamic_thresholding_ratio', 'rescale_betas_zero_snr', 'use_exponential_sigmas', 'euler_at_final', 'lambda_min_clipped', 'solver_order', 'variance_type', 'thresholding', 'lower_order_final', 'use_beta_sigmas', 'algorithm_type', 'use_lu_lambdas', 'solver_type'} was not found in config. Values will be initialized to default values.
# Steps:  98% 4900/5000 [2:01:29<01:44,  1.04s/it, loss=0.0689, lr=5.03e-6]11/07/2024 17:00:18 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'image_encoder', 'feature_extractor'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'final_sigmas_type', 'timestep_type', 'rescale_betas_zero_snr', 'use_exponential_sigmas', 'sigma_min', 'sigma_max', 'use_beta_sigmas'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2184.05it/s]
# {'final_sigmas_type', 'dynamic_thresholding_ratio', 'rescale_betas_zero_snr', 'use_exponential_sigmas', 'euler_at_final', 'lambda_min_clipped', 'solver_order', 'variance_type', 'thresholding', 'lower_order_final', 'use_beta_sigmas', 'algorithm_type', 'use_lu_lambdas', 'solver_type'} was not found in config. Values will be initialized to default values.
# Steps: 100% 5000/5000 [2:03:57<00:00,  1.08it/s, loss=0.0617, lr=4.93e-10]11/07/2024 17:02:46 - INFO - __main__ - Saving embeddings
# 11/07/2024 17:02:46 - INFO - __main__ - Saving embeddings
# 11/07/2024 17:02:46 - INFO - accelerate.accelerator - Saving current state to /content/drive/My Drive/results/textinv/SDXL/nils/checkpoint-5000
# 11/07/2024 17:02:47 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDXL/nils/checkpoint-5000/model.safetensors
# 11/07/2024 17:02:52 - INFO - accelerate.checkpointing - Model weights saved in /content/drive/My Drive/results/textinv/SDXL/nils/checkpoint-5000/model_1.safetensors
# 11/07/2024 17:02:54 - INFO - accelerate.checkpointing - Optimizer state saved in /content/drive/My Drive/results/textinv/SDXL/nils/checkpoint-5000/optimizer.bin
# 11/07/2024 17:02:54 - INFO - accelerate.checkpointing - Scheduler state saved in /content/drive/My Drive/results/textinv/SDXL/nils/checkpoint-5000/scheduler.bin
# 11/07/2024 17:02:54 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/drive/My Drive/results/textinv/SDXL/nils/checkpoint-5000/sampler.bin
# 11/07/2024 17:02:54 - INFO - accelerate.checkpointing - Random states saved in /content/drive/My Drive/results/textinv/SDXL/nils/checkpoint-5000/random_states_0.pkl
# 11/07/2024 17:02:54 - INFO - __main__ - Saved state to /content/drive/My Drive/results/textinv/SDXL/nils/checkpoint-5000
# 11/07/2024 17:02:54 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'image_encoder', 'feature_extractor'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'final_sigmas_type', 'timestep_type', 'rescale_betas_zero_snr', 'use_exponential_sigmas', 'sigma_min', 'sigma_max', 'use_beta_sigmas'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2099.25it/s]
# {'final_sigmas_type', 'dynamic_thresholding_ratio', 'rescale_betas_zero_snr', 'use_exponential_sigmas', 'euler_at_final', 'lambda_min_clipped', 'solver_order', 'variance_type', 'thresholding', 'lower_order_final', 'use_beta_sigmas', 'algorithm_type', 'use_lu_lambdas', 'solver_type'} was not found in config. Values will be initialized to default values.
# Steps: 100% 5000/5000 [2:04:47<00:00,  1.08it/s, loss=0.106, lr=0]        11/07/2024 17:03:36 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: business headshot of a <sks> man.
# {'image_encoder', 'feature_extractor'} was not found in config. Values will be initialized to default values.
# Keyword arguments {'safety_checker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'final_sigmas_type', 'timestep_type', 'rescale_betas_zero_snr', 'use_exponential_sigmas', 'sigma_min', 'sigma_max', 'use_beta_sigmas'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 2334.43it/s]
# {'final_sigmas_type', 'dynamic_thresholding_ratio', 'rescale_betas_zero_snr', 'use_exponential_sigmas', 'euler_at_final', 'lambda_min_clipped', 'solver_order', 'variance_type', 'thresholding', 'lower_order_final', 'use_beta_sigmas', 'algorithm_type', 'use_lu_lambdas', 'solver_type'} was not found in config. Values will be initialized to default values.
# 11/07/2024 17:04:17 - INFO - __main__ - Saving embeddings
# 11/07/2024 17:04:17 - INFO - __main__ - Saving embeddings
# wandb: 282.099 MB of 286.290 MB uploaded
# wandb: 282.099 MB of 286.290 MB uploaded
# wandb:
# wandb: 282.099 MB of 286.290 MB uploaded
# wandb:
# wandb: Run history:
# wandb: loss ▄▃▅▄▄▅▃▅▆▅▇▁▃▃▂█▅▃▄▅▁▄▃▆▅▂▄▁▂▆▁▇▃▃█▅▄▅▂▃
# wandb:   lr ████████▇▇▇▇▇▆▆▆▅▅▅▅▅▅▄▄▄▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb: loss 0.10647
# wandb:   lr 0
# wandb:
# wandb: 🚀 View run dandy-donkey-104 at: https://wandb.ai/lnikolei-university-of-cologne/textual_inversion/runs/8uqrehp7
# wandb: ⭐️ View project at: https://wandb.ai/lnikolei-university-of-cologne/textual_inversion
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 204 other file(s)
# wandb: Find logs at: ./wandb/run-20241107_145848-8uqrehp7/logs
# /usr/local/lib/python3.10/dist-packages/wandb/sdk/wandb_run.py:2386: UserWarning: Run (8uqrehp7) is finished. The call to `_console_raw_callback` will be ignored. Please make sure that you are using an active run.
#   lambda data: self._console_raw_callback("stderr", data),
# Steps: 100% 5000/5000 [2:05:32<00:00,  1.51s/it, loss=0.106, lr=0]
# Removed /content/train_images/nils_5.jpg
# Removed /content/train_images/nils_2.jpg
# Removed /content/train_images/nils_6.jpg
# Removed /content/train_images/nils_1.jpg
# Removed /content/train_images/nils_9.jpg
# Removed /content/train_images/nils_3.jpg
# Removed /content/train_images/nils_10.jpg
# Removed /content/train_images/nils_4.jpg
# Removed /content/train_images/nils_7.jpg
# Removed /content/train_images/nils_8.jpg
# Directory /content/train_images has been emptied.
